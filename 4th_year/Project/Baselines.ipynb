# %% [markdown]
# # Train/dev split

# %%
from sklearn.model_selection import train_test_split

# %%
texts, ids = [], []
with open('train_reviews.txt') as f:
    for line in f:
        text_id, text = line.rstrip('\r\n').split('\t')
        texts.append(text)
        ids.append(text_id)

# %%
train_texts, dev_texts, train_ids, dev_ids = train_test_split(texts, ids)

# %%
train_aspects, dev_aspects = [], []
with open('train_aspects.txt') as f:
    for line in f:
        line = line.rstrip('\r\n')
        text_id = line.split('\t')[0]
        if text_id in train_ids:
            train_aspects.append(line)
        if text_id in dev_ids:
            dev_aspects.append(line)

# %%
train_sentiment, dev_sentiment = [], []
with open('train_cats.txt') as f:
    for line in f:
        line = line.rstrip('\r\n')
        text_id = line.split('\t')[0]
        if text_id in train_ids:
            train_sentiment.append(line)
        if text_id in dev_ids:
            dev_sentiment.append(line)

# %%
with open('train_split_aspects.txt', 'w') as f:
    for l in train_aspects:
        print(l, file=f)
with open('dev_aspects.txt', 'w') as f:
    for l in dev_aspects:
        print(l, file=f)
with open('train_split_reviews.txt', 'w') as f:
    for i, l in zip(train_ids, train_texts):
        print(i, l, sep="\t", file=f)
with open('dev_reviews.txt', 'w') as f:
    for i, l in zip(dev_ids, dev_texts):
        print(i, l, sep="\t", file=f)
with open('train_split_cats.txt', 'w') as f:
    for l in train_sentiment:
        print(l, file=f)
with open('dev_cats.txt', 'w') as f:
    for l in dev_sentiment:
        print(l, file=f)

# %% [markdown]
# # Baseline 1,2: категория и тональность упоминаний
#
# Выделяем только аспекты, встретившиеся в train'е, приписываем самую частотную категорию.

# %%
import pandas as pd

# %%
train_asp = pd.read_csv(
    'train_split_aspects.txt', 
    delimiter='\t', 
    names=['text_id', 'category', 'mention', 'start', 'end', 'sentiment']
)
train_texts = pd.read_csv('train_split_reviews.txt', delimiter='\t', names=['text_id','text'])

# %%
import stanza
stanza.download('ru')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2021-12-25 20:29:40 INFO: Downloading default packages for language: ru (Russian)...
# 2021-12-25 20:29:42 INFO: File exists: /Users/rhubarb/stanza_resources/ru/default.zip.
# 2021-12-25 20:29:48 INFO: Finished downloading models and saved to /Users/rhubarb/stanza_resources.

# %%
nlp = stanza.Pipeline('ru', processors='tokenize,lemma')
# Out:
# 2021-12-25 20:29:48 INFO: Loading these models for language: ru (Russian):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | syntagrus |
# | lemma     | syntagrus |
# =========================
#
# 2021-12-25 20:29:48 INFO: Use device: cpu
# 2021-12-25 20:29:48 INFO: Loading: tokenize
# 2021-12-25 20:29:48 INFO: Loading: lemma
# 2021-12-25 20:29:48 INFO: Done loading processors!

# %%
def normalize(text):
    doc = nlp(text)
    words = [word.lemma for sent in doc.sentences for word in sent.words]
    return words

# %%
from collections import defaultdict, Counter

# %%
train_asp['norm_mention'] = [tuple(normalize(m)) for m in train_asp['mention']]

# %% [markdown]
# Строим частотный словарь "токенизированное упоминание + категория"
#
# Категория - аспектная категория или тональность

# %%
def get_mention_category(data, cat_type):
    mention_categories = data.value_counts(subset=['norm_mention', cat_type])
    mention_categories_dict = defaultdict(dict)
    for key, value in mention_categories.items():
        mention_categories_dict[key[0]][key[1]] = value
    return {k: Counter(v).most_common(1)[0][0] for k, v in mention_categories_dict.items()}

# %%
best_mention_cat = get_mention_category(train_asp, 'category')

# %%
best_mention_cat
# Out:
# {('ресторан',): 'Whole',
#  ('интерьер',): 'Interior',
#  ('обслуживание',): 'Service',
#  ('официант',): 'Service',
#  ('заведение',): 'Whole',
#  ('кухня',): 'Food',
#  ('место',): 'Whole',
#  ('блюдо',): 'Food',
#  ('еда',): 'Food',
#  ('цена',): 'Price',
#  ('персонал',): 'Service',
#  ('пиво',): 'Food',
#  ('порция',): 'Food',
#  ('официантка',): 'Service',
#  ('атмосфера',): 'Interior',
#  ('меню',): 'Food',
#  ('музыка',): 'Interior',
#  ('сервис',): 'Service',
#  ('встретить',): 'Service',
#  ('девушка',): 'Service',
#  ('горячий',): 'Food',
#  ('десерт',): 'Food',
#  ('администратор',): 'Service',
#  ('обстановка',): 'Interior',
#  ('вечер',): 'Whole',
#  ('салаты',): 'Food',
#  ('зал',): 'Interior',
#  ('мясо',): 'Food',
#  ('ждать',): 'Service',
#  ('обслуживал',): 'Service',
#  ('салат',): 'Food',
#  ('поесть',): 'Food',
#  ('столик',): 'Interior',
#  ('вино',): 'Food',
#  ('кафе',): 'Whole',
#  ('чай',): 'Food',
#  ('принести',): 'Service',
#  ('вкус',): 'Food',
#  ('напиток',): 'Food',
#  ('молодой', 'человек'): 'Service',
#  ('шашлык',): 'Food',
#  ('живой', 'музыка'): 'Interior',
#  ('рыба',): 'Food',
#  ('заказ',): 'Service',
#  ('пицца',): 'Food',
#  ('закуска',): 'Food',
#  ('заказать',): 'Service',
#  ('провести', 'время'): 'Whole',
#  ('ресторанчик',): 'Whole',
#  ('суп',): 'Food',
#  ('готовить',): 'Food',
#  ('счет',): 'Price',
#  ('свинина',): 'Food',
#  ('кофе',): 'Food',
#  ('паб',): 'Whole',
#  ('пасту',): 'Food',
#  ('соус',): 'Food',
#  ('диваны',): 'Interior',
#  ('паста',): 'Food',
#  ('покушать',): 'Food',
#  ('съесть',): 'Food',
#  ('стол',): 'Interior',
#  ('принести', 'меню'): 'Service',
#  ('алкоголь',): 'Food',
#  ('мороженое',): 'Food',
#  ('официантки',): 'Service',
#  ('ребята',): 'Service',
#  ('приносить',): 'Service',
#  ('человек',): 'Service',
#  ('ужин',): 'Food',
#  ('хлеб',): 'Food',
#  ('диванчики',): 'Interior',
#  ('предложить',): 'Service',
#  ('блюда',): 'Food',
#  ('торт',): 'Food',
#  ('приготовлено',): 'Food',
#  ('десерты',): 'Food',
#  ('помещение',): 'Interior',
#  ('рассказать',): 'Service',
#  ('кальян',): 'Food',
#  ('работать',): 'Service',
#  ('встречать',): 'Service',
#  ('ресторану',): 'Whole',
#  ('впечатление',): 'Whole',
#  ('менеджер',): 'Service',
#  ('напитка',): 'Food',
#  ('проводить',): 'Service',
#  ('морс',): 'Food',
#  ('поужинать',): 'Food',
#  ('сотрудник',): 'Service',
#  ('второй', 'этаж'): 'Interior',
#  ('выпить',): 'Food',
#  ('свет',): 'Interior',
#  ('детский', 'комната'): 'Interior',
#  ('десерта',): 'Food',
#  ('администрация',): 'Service',
#  ('заказ', 'принять'): 'Service',
#  ('праздник',): 'Whole',
#  ('заказать', 'столик'): 'Service',
#  ('пообедать',): 'Food',
#  ('диванчик',): 'Interior',
#  ('суша',): 'Food',
#  ('закусок',): 'Food',
#  ('рис',): 'Food',
#  ('советовать',): 'Service',
#  ('скидку',): 'Price',
#  ('роллы',): 'Food',
#  ('местечко',): 'Whole',
#  ('говядина',): 'Food',
#  ('тирамису',): 'Food',
#  ('мебель',): 'Interior',
#  ('свеча',): 'Interior',
#  ('гардероб',): 'Interior',
#  ('выбор', 'блюдо'): 'Food',
#  ('горячий', 'блюдо'): 'Food',
#  ('стул',): 'Interior',
#  ('подходить',): 'Service',
#  ('бармен',): 'Service',
#  ('шампанское',): 'Food',
#  ('помочь',): 'Service',
#  ('шеф', '-', 'повару'): 'Food',
#  ('овощ',): 'Food',
#  ('бизнес', '-', 'ленч'): 'Food',
#  ('мужчина',): 'Service',
#  ('пробовать',): 'Food',
#  ('цезарь', 'с', 'креветками'): 'Food',
#  ('пить',): 'Food',
#  ('вид', 'из', 'окно'): 'Interior',
#  ('китайский', 'кухня'): 'Food',
#  ('салями',): 'Food',
#  ('коктейли',): 'Food',
#  ('коктейль',): 'Food',
#  ('салатама',): 'Food',
#  ('заказ', 'принести'): 'Service',
#  ('стейк',): 'Food',
#  ('выбор', 'пиво'): 'Food',
#  ('филадельфия',): 'Food',
#  ('гарнир',): 'Food',
#  ('арагви',): 'Whole',
#  ('гардеробщик',): 'Service',
#  ('освещение',): 'Interior',
#  ('зал', 'для', 'курящих'): 'Interior',
#  ('попить',): 'Food',
#  ('посуда',): 'Interior',
#  ('скидка',): 'Price',
#  ('зал', 'для', 'некурящих'): 'Interior',
#  ('готовят',): 'Food',
#  ('тан', 'жен'): 'Whole',
#  ('чек',): 'Price',
#  ('танцпол',): 'Interior',
#  ('обслуживать', 'персонал'): 'Service',
#  ('оформлено',): 'Interior',
#  ('масло',): 'Food',
#  ('поварам',): 'Food',
#  ('есть',): 'Food',
#  ('фрукт',): 'Food',
#  ('управляющий',): 'Service',
#  ('блюдох',): 'Food',
#  ('водка',): 'Food',
#  ('хачапури',): 'Food',
#  ('провожать',): 'Service',
#  ('обедать',): 'Food',
#  ('улыбаться',): 'Service',
#  ('устрица',): 'Food',
#  ('супчики',): 'Food',
#  ('столик', 'заказать'): 'Service',
#  ('выбор', 'алкоголь'): 'Food',
#  ('перекусить',): 'Food',
#  ('принять', 'заказ'): 'Service',
#  ('кушаль',): 'Food',
#  ('стейки',): 'Food',
#  ('залы',): 'Interior',
#  ('подать',): 'Service',
#  ('подача',): 'Food',
#  ('повара',): 'Food',
#  ('столика',): 'Interior',
#  ('соотношение', 'цена/качество'): 'Price',
#  ('здороваются',): 'Service',
#  ('пабе',): 'Whole',
#  ('палочка',): 'Food',
#  ('стейк', 'из', 'тунца'): 'Food',
#  ('закуска', 'к', 'пиву'): 'Food',
#  ('палтуса',): 'Food',
#  ('соуса',): 'Food',
#  ('пирожной',): 'Food',
#  ('панакота',): 'Food',
#  ('подойти',): 'Service',
#  ('подушка',): 'Interior',
#  ('заказали', 'столик'): 'Service',
#  ('персонал', 'ресторан'): 'Service',
#  ('паст',): 'Food',
#  ('помогли',): 'Service',
#  ('сок',): 'Food',
#  ('первый', 'блюдо'): 'Food',
#  ('первый', 'этаж'): 'Interior',
#  ('заведением',): 'Whole',
#  ('свободный', 'столик'): 'Interior',
#  ('знать', 'меню'): 'Service',
#  ('провести', 'вечер'): 'Whole',
#  ('курицу',): 'Food',
#  ('кухне',): 'Whole',
#  ('обслуживать',): 'Service',
#  ('лаваш',): 'Food',
#  ('рояль',): 'Interior',
#  ('лапша', 'с', 'креветками'): 'Food',
#  ('обслуживало',): 'Service',
#  ('ресторанчике',): 'Whole',
#  ('няня',): 'Service',
#  ('проводить', 'до', 'столик'): 'Service',
#  ('сажать',): 'Service',
#  ('проводить', 'к', 'стол'): 'Service',
#  ('проводить', 'к', 'столику'): 'Service',
#  ('наполеон',): 'Food',
#  ('продукт',): 'Food',
#  ('наелась',): 'Food',
#  ('место', 'для', 'танец'): 'Interior',
#  ('набережную',): 'Whole',
#  ('публика',): 'Interior',
#  ('рассказывать',): 'Service',
#  ('рыбка',): 'Food',
#  ('обслуживающем', 'персонал'): 'Service',
#  ('посещение',): 'Whole',
#  ('отдать',): 'Service',
#  ('итальянский', 'блюдо'): 'Food',
#  ('итальянский', 'кухня'): 'Food',
#  ('итальянский', 'ресторан'): 'Whole',
#  ('посоветуют',): 'Service',
#  ('оформлен',): 'Food',
#  ('каминный', 'зал'): 'Interior',
#  ('отношение',): 'Service',
#  ('отдохнули',): 'Whole',
#  ('сервировка',): 'Interior',
#  ('прибор',): 'Interior',
#  ('креветки',): 'Food',
#  ('осьминог',): 'Food',
#  ('качество', 'еда'): 'Food',
#  ('приготовленный',): 'Food',
#  ('овощ', 'на', 'грило'): 'Food',
#  ('санторини',): 'Whole',
#  ('обстановка', 'в', 'ресторан'): 'Interior',
#  ('концерт',): 'Interior',
#  ('обслужили',): 'Service',
#  ('салат', '"', 'Цезарь', '"'): 'Food',
#  ('японский', 'кухня'): 'Food',
#  ('повар',): 'Service',
#  ('чукка', 'салат'): 'Food',
#  ('десерт', 'тирамису'): 'Food',
#  ('вкус', 'блюдо'): 'Food',
#  ('чаевые',): 'Service',
#  ('улыбаются',): 'Service',
#  ('суши',): 'Food',
#  ('ценник',): 'Price',
#  ('Токио',): 'Whole',
#  ('Цезарь',): 'Food',
#  ('гость',): 'Service',
#  ('вентиляция',): 'Interior',
#  ('аппетит',): 'Whole',
#  ('хинкали',): 'Food',
#  ('девушка', 'официантка'): 'Service',
#  ('выбор',): 'Food',
#  ('бронировать',): 'Service',
#  ('виски',): 'Food',
#  ('телятины',): 'Food',
#  ('убирать',): 'Service',
#  ('бронировать', 'стол'): 'Service',
#  ('сыр',): 'Food',
#  ('Нельсон', 'паб'): 'Whole',
#  ('барную', 'стойка'): 'Interior',
#  ('уносят',): 'Service',
#  ('чебурек',): 'Whole',
#  ('дизайн',): 'Interior',
#  ('бифштекс',): 'Food',
#  ('утка',): 'Food',
#  ('баклажан',): 'Food',
#  ('холодный', 'закуска'): 'Food',
#  ('шоколадный', 'фонтан'): 'Food',
#  ('блюде',): 'Food',
#  ('встретила',): 'Service',
#  ('чебуреки',): 'Food',
#  ('директор',): 'Service',
#  ('тарелка',): 'Interior',
#  ('детский', 'меню'): 'Food',
#  ('вкусно',): 'Food',
#  ('блин',): 'Food',
#  ('проводить', 'до', 'наш', 'столик'): 'Service',
#  ('форель', ',', 'запеченная', 'с', 'овощ'): 'Food',
#  ('харбина', 'на', 'приморской'): 'Interior',
#  ('продегустировать',): 'Food',
#  ('проводить', 'за', 'столик'): 'Service',
#  ('французский', 'красный', 'сухой', 'вино'): 'Food',
#  ('программа',): 'Interior',
#  ('харбин', 'на', 'приморской'): 'Whole',
#  ('фуа', '-', 'грой'): 'Food',
#  ('фотан',): 'Interior',
#  ('провожает', 'к', 'стол'): 'Service',
#  ('фроузен', 'парфе'): 'Food',
#  ('франческо',): 'Whole',
#  ('хлебный', 'греночки', 'с', 'сыр'): 'Food',
#  ('проводить', 'до', 'место'): 'Service',
#  ('принёс', 'меню'): 'Service',
#  ('хостесс',): 'Service',
#  ('принести', 'специи'): 'Service',
#  ('хостес',): 'Service',
#  ('приносили',): 'Service',
#  ('холодный', 'рыбный', 'рулет'): 'Food',
#  ('холодный', 'закусок'): 'Food',
#  ('холодный', 'закуск'): 'Food',
#  ('хозяин',): 'Whole',
#  ('проводили',): 'Service',
#  ('приправ',): 'Food',
#  ('хлебный', 'тарелка'): 'Food',
#  ('приправлен',): 'Food',
#  ('хлебный', 'корзина'): 'Food',
#  ('проведенным', 'вечер'): 'Whole',
#  ('хлебно', 'козинка'): 'Food',
#  ('провести', 'до', 'столик'): 'Service',
#  ('провести', 'там', 'время'): 'Whole',
#  ('прожаренное',): 'Food',
#  ('суп', 'чанахи'): 'Food',
#  ('прожарка',): 'Food',
#  ('разнообразие', 'в', 'меню'): 'Food',
#  ('уютно',): 'Interior',
#  ('разрешать',): 'Service',
#  ('расплачиваться', 'по', 'счет'): 'Service',
#  ('расположенный',): 'Interior',
#  ('расположиться',): 'Whole',
#  ('уют',): 'Interior',
#  ('уходить',): 'Service',
#  ('результат', 'вместе', 'с', 'чаевыми'): 'Price',
#  ('ухо',): 'Food',
#  ('фонтан', 'в', 'центр', 'зал'): 'Interior',
#  ('утка', 'по-пекинский'): 'Food',
#  ('утка', 'в', 'апельсинов', 'соусе'): 'Food',
#  ('ресторан', '"', 'Оливье', '"'): 'Whole',
#  ('ресторан', '"', 'долина', '"'): 'Whole',
#  ('ресторан', '"', 'крапива', '"'): 'Whole',
#  ('утинуй', 'грудка', 'гриль', 'с', 'фрукт'): 'Food',
#  ('ресторан', '"', 'мамалыга', '"'): 'Whole',
#  ('ресторан', '"', 'русский', 'китч', '"'): 'Whole',
#  ('ресторан', '"', 'фаворит', '"'): 'Whole',
#  ('разнообразие',): 'Food',
#  ('размер', 'порция'): 'Food',
#  ('размер', 'порций'): 'Food',
#  ('разложить', 'прибор'): 'Service',
#  ('пролил',): 'Service',
#  ('пространство',): 'Interior',
#  ('фонарик',): 'Interior',
#  ('профессионал',): 'Service',
#  ('прощаются',): 'Service',
#  ('фокачча', 'с', 'прованский', 'трава', 'и', 'сыр', 'пармезан'): 'Food',
#  ('пустой', 'помещение'): 'Interior',
#  ('цвет',): 'Interior',
#  ('пшеничное', 'и', 'ячменное', 'пиво'): 'Food',
#  ('пюре',): 'Food',
#  ('работа',): 'Service',
#  ('работа', 'она', 'выполнял'): 'Service',
#  ('фиш', '&о', 'чипс'): 'Food',
#  ('рагу',): 'Food',
#  ('фирменное', 'блюдо'): 'Food',
#  ('радио',): 'Whole',
#  ('филки', 'норвежское', 'лосося', 'с', 'овощ', 'и', 'креветками'): 'Food',
#  ('развлекательная', 'программа'): 'Interior',
#  ('раздель', '-', 'проводить'): 'Service',
#  ('уютный',): 'Interior',
#  ('разливал', 'шампанское'): 'Service',
#  ('хочухарчо',): 'Whole',
#  ('приготовлен',): 'Food',
#  ('цветочный', 'композиция'): 'Interior',
#  ('полумрак',): 'Interior',
#  ('пожарские', 'котлета'): 'Food',
#  ('поиинтересовался',): 'Service',
#  ('показать',): 'Service',
#  ('шеф', 'повара'): 'Food',
#  ('шеф', '-', 'повара'): 'Service',
#  ('показывать',): 'Service',
#  ('шеф', '-', 'повар'): 'Service',
#  ('пол', 'порция'): 'Food',
#  ('поленте',): 'Whole',
#  ('полусухое',): 'Food',
#  ('цезар',): 'Food',
#  ('шашлыка', 'из', 'лосося'): 'Food',
#  ('помидор',): 'Food',
#  ('шашлык', 'ягненка'): 'Food',
#  ('шашлык', 'из', 'курицы'): 'Food',
#  ('помогли', 'с', 'заказом'): 'Service',
#  ('шашлык', 'из', 'куриной', 'грудки'): 'Food',
#  ('шашлык', 'из', 'баранина', 'на', 'кость', 'и', 'мякоть'): 'Food',
#  ('шавермы',): 'Food',
#  ('помочь', 'с', 'выбор'): 'Service',
#  ('шаверму', 'с', 'курица'): 'Food',
#  ('шеф', 'повару'): 'Food',
#  ('шеф-повар',): 'Service',
#  ('шеф-повар', 'ресторан'): 'Service',
#  ('подсказать',): 'Service',
#  ('яблочный', 'пирог'): 'Food',
#  ('эспрессо',): 'Food',
#  ('поворам',): 'Food',
#  ('подавались',): 'Service',
#  ('подавать',): 'Service',
#  ('подарок', 'от', 'шеф-повар'): 'Service',
#  ('шурвы',): 'Food',
#  ('шторы',): 'Interior',
#  ('подать', 'меню'): 'Service',
#  ('шпинат',
#   'с',
#   'голубой',
#   'сыр',
#   'под',
#   'фантастический',
#   'заправкой'): 'Food',
#  ('шоу',): 'Interior',
#  ('шоколадная', 'шкатулка'): 'Food',
#  ('подача', 'блюдо'): 'Food',
#  ('подача', 'мясо'): 'Food',
#  ('подготовить', 'закуска'): 'Service',
#  ('подождать',): 'Service',
#  ('шницель',): 'Food',
#  ('подскажет',): 'Service',
#  ('подскажут',): 'Service',
#  ('пообедали',): 'Food',
#  ('чистота', 'скатерт'): 'Interior',
#  ('попили',): 'Food',
#  ('предлагать', 'пробовать'): 'Service',
#  ('центр', 'зал'): 'Interior',
#  ('предложить', 'меню'): 'Service',
#  ('ценовой', 'категория'): 'Price',
#  ('предложить', 'напиток'): 'Service',
#  ('предложить', 'присесть'): 'Service',
#  ('предложить', 'сесть'): 'Service',
#  ('предоставить',): 'Service',
#  ('предупредить',): 'Service',
#  ('предупрежден',): 'Service',
#  ('цена', 'на', 'кальян'): 'Price',
#  ('цена', 'на', 'вино'): 'Price',
#  ('приветливая',): 'Service',
#  ('приглашать',): 'Service',
#  ('ресторан', 'italy'): 'Whole',
#  ('цезарь', 'с', 'лососем'): 'Food',
#  ('приготовление',): 'Food',
#  ('приготовленное',): 'Food',
#  ('прием',): 'Service',
#  ('цезарь',): 'Food',
#  ('принесли',): 'Service',
#  ('предложили',): 'Service',
#  ('предлагать',): 'Service',
#  ('чипсы',): 'Food',
#  ('предварительный', 'резервация'): 'Service',
#  ('человек', 'из', 'персонал'): 'Service',
#  ('попрощаться',): 'Service',
#  ('порекомендовал',): 'Service',
#  ('чебуреки', 'с', 'сыр', 'сулугуни', 'и', 'зелень'): 'Food',
#  ('порция', 'салат'): 'Food',
#  ('посетитель', 'ВИП', '-', 'зал'): 'Interior',
#  ('чебурека',): 'Food',
#  ('послевкусие',): 'Food',
#  ('посоветует',): 'Service',
#  ('постное', 'меню'): 'Food',
#  ('чай', 'с', 'чабрец'): 'Food',
#  ('чай', 'с', 'лимон', 'и', 'чабрец'): 'Food',
#  ('чай', 'с', 'десерт'): 'Food',
#  ('потанцевали',): 'Interior',
#  ('потанцевать',): 'Interior',
#  ('чай', 'по', 'восточный', 'с', 'инжирной', 'варенье'): 'Food',
#  ('поужиналь',): 'Food',
#  ('чаек',): 'Food',
#  ('появиться',): 'Service',
#  ('появляться',): 'Service',
#  ('ресторан', '"', 'эскалибур', '"'): 'Whole',
#  ('ресторан', 'мисо'): 'Whole',
#  ('ресторан', 'аллегро'): 'Whole',
#  ('сырные', 'палочка'): 'Food',
#  ('смузи', 'овощной'): 'Food',
#  ('собеседник',): 'Service',
#  ('собрать',): 'Service',
#  ('совет',): 'Service',
#  ('совет', 'по', 'меню'): 'Service',
#  ('тарелка', 'фрукт'): 'Food',
#  ('тарелка', 'убирать'): 'Service',
#  ('тарелка', 'к', 'пиву'): 'Food',
#  ('соленый',): 'Food',
#  ('соленый', 'гриб'): 'Food',
#  ('соотношение', 'цена', 'и', 'качество'): 'Price',
#  ('танцы',): 'Interior',
#  ('сорба',): 'Food',
#  ('сорбет',): 'Food',
#  ('состав', 'блюдо'): 'Food',
#  ('состав', 'десерта'): 'Food',
#  ('танец',): 'Interior',
#  ('сотрудник', 'ресторан'): 'Service',
#  ('тан', 'жена'): 'Whole',
#  ('тамаду',): 'Service',
#  ('сытый', 'хавронья', 'из', 'свинина'): 'Food',
#  ('сырныйи', 'шарик'): 'Food',
#  ('сырные', 'шарик'): 'Food',
#  ('смузи', 'злаковый'): 'Food',
#  ('тарелку', 'к', 'пиву'): 'Food',
#  ('смотреть', 'за', 'стол'): 'Service',
#  ('террасу',): 'Whole',
#  ('тест',): 'Food',
#  ('сдача',): 'Price',
#  ('сдача', 'ждать'): 'Service',
#  ('селедка',): 'Food',
#  ('сельдь', 'под', 'шуба', '…', 'с', 'краб'): 'Food',
#  ('тертым', 'сыр'): 'Food',
#  ('сервировку', 'блюдо'): 'Food',
#  ('сервируют',): 'Service',
#  ('скатерти', 'на', 'стол'): 'Interior',
#  ('террас',): 'Whole',
#  ('смотреть', 'за', 'посетитель'): 'Service',
#  ('теплый', 'мексиканским', 'салат'): 'Food',
#  ('скиснуть',): 'Food',
#  ('скорость',): 'Service',
#  ('скульптур',): 'Interior',
#  ('следить', 'за', 'стол'): 'Service',
#  ('телятина',): 'Food',
#  ('слушать',): 'Service',
#  ('телевизор',): 'Interior',
#  ('твинс',): 'Whole',
#  ('соус', 'без', 'анчоусов'): 'Food',
#  ('сырной', 'тарелка'): 'Food',
#  ('усадиль',): 'Service',
#  ('сырная', 'тарелка'): 'Food',
#  ('стейком',): 'Food',
#  ('стейку',): 'Food',
#  ('стена',): 'Interior',
#  ('стоимость', 'ужин'): 'Price',
#  ('сухарик',): 'Food',
#  ('супчик',): 'Food',
#  ('стол', 'для', 'рисование'): 'Interior',
#  ('стол', 'забронировали'): 'Service',
#  ('супами',): 'Food',
#  ('столик', 'бронировали'): 'Service',
#  ('суп-харчо',): 'Food',
#  ('столик', 'бронировать'): 'Service',
#  ('столик', 'забронировали'): 'Service',
#  ('суп-пюра', 'из', 'белый', 'гриб'): 'Food',
#  ('столик', 'не', 'заказывать'): 'Service',
#  ('столовая',): 'Interior',
#  ('стрейк', 'Нью-Йорк'): 'Food',
#  ('суп-вино',): 'Whole',
#  ('стульчики', 'для', 'кормление'): 'Interior',
#  ('судака',): 'Food',
#  ('судака', 'фаршированный'): 'Food',
#  ('суп', 'из', 'печеного', 'чеснок'): 'Food',
#  ('суша', '-', 'бар'): 'Whole',
#  ('стейк-', 'хаусах'): 'Whole',
#  ('стейк', 'с', 'соус', 'из', 'белый', 'гриб'): 'Food',
#  ('спокойный',): 'Interior',
#  ('соус', 'из', 'петрушка'): 'Food',
#  ('соус', 'к', 'мясо', 'и', 'картофелю'): 'Food',
#  ('соус', 'тар-тар'): 'Food',
#  ('сырная', 'и', 'мясная', 'тарелка'): 'Food',
#  ('спагетть',): 'Food',
#  ('сыр', 'филадельфия'): 'Food',
#  ('спагетть', 'карбонара'): 'Food',
#  ('спагетть', 'с', 'фрикаделька'): 'Food',
#  ('съела',): 'Food',
#  ('спиртной', 'напитка'): 'Food',
#  ('спрашивать',): 'Service',
#  ('стейк', 'рибай'): 'Food',
#  ('счёт',): 'Service',
#  ('стандартный', 'блюдо'): 'Food',
#  ('счет', 'мы', 'принести'): 'Service',
#  ('стейк', 'из', 'говядина', 'с', 'шпинат'): 'Food',
#  ('счесть',): 'Service',
#  ('стейк', 'из', 'лосося'): 'Food',
#  ('стейк', 'из', 'мраморный', 'говядина'): 'Food',
#  ('сушки', 'с', 'перчиком'): 'Food',
#  ('свободный', 'место'): 'Interior',
#  ('свиную', 'рульку'): 'Food',
#  ('свинина',
#   'с',
#   'сыр',
#   'фета',
#   ',',
#   'фисташка',
#   'и',
#   'грибно',
#   'соус'): 'Food',
#  ('свинина', 'с', 'гриб'): 'Food',
#  ('ужинали',): 'Food',
#  ('ужинал',): 'Food',
#  ('руккола', 'с', 'креветками'): 'Food',
#  ('угощение',): 'Food',
#  ('уголок',): 'Interior',
#  ('руководство', 'ресторан'): 'Whole',
#  ('рулет', 'из', 'лосося', 'с', 'зелено', 'спаржай'): 'Food',
#  ('рулетики', 'из', 'баклажан'): 'Food',
#  ('рулетики', 'с', 'гриб'): 'Food',
#  ('убираются',): 'Interior',
#  ('рыба', '-', 'стейк', 'из', 'форель'): 'Food',
#  ('убиралась',): 'Service',
#  ('тыквенный', 'суп'): 'Food',
#  ('сажать', 'за', 'столик'): 'Service',
#  ('саксофонист',): 'Interior',
#  ('тушеная', 'телятина'): 'Food',
#  ('тунцом',): 'Food',
#  ('тунец', 'с', 'овощ', 'гриль'): 'Food',
#  ('салат', '"', 'кавказский', '"'): 'Food',
#  ('салат', '"', 'лагуна', '"'): 'Food',
#  ('салат', '"', 'розана', '"'): 'Food',
#  ('салат', '"', 'салмон', '"', 'с', 'лососем'): 'Food',
#  ('салат', 'Цезарь'): 'Food',
#  ('роллы', 'на', 'грило'): 'Food',
#  ('украшение', 'зал'): 'Interior',
#  ('роллы', 'запеченные', 'на', 'уголь'): 'Food',
#  ('ресторан', 'харбин', 'на', 'приморской'): 'Whole',
#  ('упаковано',): 'Service',
#  ('ресторан', 'гламур'): 'Whole',
#  ('ресторан', 'китайский', 'кухня'): 'Whole',
#  ('ресторан', 'кухню'): 'Whole',
#  ('ресторан', 'марчеллис'): 'Whole',
#  ('суп', 'с', 'норвежским', 'лососем'): 'Food',
#  ('ресторан', 'на', 'приморской'): 'Whole',
#  ('ресторан', 'палкин'): 'Whole',
#  ('ресторан', 'трес', 'амигос'): 'Whole',
#  ('ресторан', 'харбин', 'на', 'академическая'): 'Whole',
#  ('ресторану', 'La', 'fabrik'): 'Whole',
#  ('роллы', 'без', 'рис'): 'Food',
#  ('упакована',): 'Service',
#  ('рибай',): 'Food',
#  ('ризотто',): 'Food',
#  ('ризотто', 'с', 'белый', 'гриб'): 'Food',
#  ('ризотто', 'с', 'спраж', 'и', 'горгонзолой'): 'Food',
#  ('рис', 'с', 'курица'): 'Food',
#  ('ролл',): 'Food',
#  ('ролл', 'филадельфия'): 'Food',
#  ('улитка',): 'Food',
#  ('салат', 'греческий'): 'Food',
#  ('салат', 'грибной'): 'Food',
#  ('салат', 'из', 'запеченох', 'овощ'): 'Food',
#  ('свежий',): 'Food',
#  ('торты',): 'Food',
#  ('салаты', '"', 'Цезарь', '"'): 'Food',
#  ('салаты', '(', 'с', 'лососем', ',', 'краб', ',', 'тунцом', ')'): 'Food',
#  ('салаты', 'из', 'язык', 'и', 'морепродукт'): 'Food',
#  ('тортом',): 'Food',
#  ('санам',): 'Whole',
#  ('тортик',): 'Food',
#  ('томатный', 'суп'): 'Food',
#  ('сациви', 'из', 'баклажан'): 'Food',
#  ('сашими',): 'Food',
#  ('свежий', 'овощ'): 'Food',
#  ('салатики',): 'Food',
#  ('томатный', 'соус'): 'Food',
#  ('светильники', '/', 'люстра'): 'Interior',
#  ('светлый', 'зал'): 'Interior',
#  ('томатный', 'пасту'): 'Food',
#  ('тираму',): 'Food',
#  ('свечи-', 'цветы'): 'Interior',
#  ('тимьян',): 'Food',
#  ('свинина', 'в', 'кисло-сладком', 'соусе'): 'Food',
#  ('тесто',): 'Food',
#  ('свинина', 'по-пекинский'): 'Food',
#  ('салату', 'цезарь'): 'Food',
#  ('салатик', '"', 'Оливье', '"'): 'Food',
#  ('туалет', 'с', 'аквариумами'): 'Interior',
#  ('салат', 'с', 'креветками', 'и', 'краб'): 'Food',
#  ('салат', 'из', 'лисичек', 'с', 'кроличья', 'печенью'): 'Food',
#  ('салат', 'из', 'лосося'): 'Food',
#  ('салат', 'из', 'морепродукт'): 'Food',
#  ('салат',
#   'из',
#   'они',
#   'меню',
#   'с',
#   '"',
#   'семга',
#   'горячий',
#   'копчение',
#   '"'): 'Food',
#  ('салат', 'из', 'свиной', 'ухо'): 'Food',
#  ('салат', 'из', 'тунца'): 'Food',
#  ('салат', 'пампелон'): 'Food',
#  ('туалет',): 'Interior',
#  ('салат', 'с', 'домашний', 'сыр'): 'Food',
#  ('салат', 'с', 'креветками'): 'Food',
#  ('салат', 'с', 'креветками', 'и', 'лист'): 'Food',
#  ('трапеза', 'итальянский', 'кухня'): 'Food',
#  ('салат', 'с', 'куриной', 'печенью'): 'Food',
#  ('салат', 'с', 'малосольное', 'лососем'): 'Food',
#  ('салат', 'с', 'рукколой', 'и', 'вяленоми', 'помидор'): 'Food',
#  ('салат', 'с', 'рыба'): 'Food',
#  ('салат', 'с', 'угрем'): 'Food',
#  ('салат', 'цезарь'): 'Food',
#  ('салат', 'цезарь', 'с', 'креветками'): 'Food',
#  ('трес', 'амигос'): 'Whole',
#  ('салатик',): 'Food',
#  ('тревелс',): 'Whole',
#  ('сладости',): 'Food',
#  ('1ом', 'этаж'): 'Interior',
#  ('площадь', 'ресторан'): 'Whole',
#  ('девушка', '(', 'официант', ')'): 'Service',
#  ('девушка', '-', 'официантки'): 'Service',
#  ('девушка', '-', 'певица'): 'Interior',
#  ('девушка', 'администратор'): 'Service',
#  ('девушка', 'официант'): 'Service',
#  ('девушка', 'официантки'): 'Service',
#  ('девченки',): 'Service',
#  ('декор',): 'Interior',
#  ('декором',): 'Interior',
#  ('делать', 'заказ'): 'Service',
#  ('деликатес',): 'Food',
#  ('делфим', 'Бар'): 'Whole',
#  ('деньги',): 'Price',
#  ('депозит', '5', 'тысяча'): 'Price',
#  ('десерт', '"', 'три', 'шоколад', '"'): 'Food',
#  ('десертик',): 'Food',
#  ('диванах',): 'Interior',
#  ('диваном',): 'Interior',
#  ('диванчики', '-', 'купе'): 'Interior',
#  ('дизайнерское', 'решение'): 'Interior',
#  ('дисконтно', 'карта'): 'Service',
#  ('дитае',): 'Whole',
#  ('добавлять', 'вино'): 'Service',
#  ('доедаль',): 'Food',
#  ('домашний', 'куриный', 'супчик'): 'Food',
#  ('домашний', 'лимонады'): 'Food',
#  ('домашний', 'мороженое'): 'Food',
#  ('домашний', 'морс'): 'Food',
#  ('допинг',): 'Food',
#  ('дораду', 'с', 'овощ'): 'Food',
#  ('девушка', '-', 'администратор'): 'Service',
#  ('девочки', '-', 'официантки'): 'Service',
#  ('выслушала',): 'Service',
#  ('девочка', '-', 'официант'): 'Service',
#  ('главный', 'зал'): 'Interior',
#  ('глобуса',): 'Whole',
#  ('говядин',): 'Food',
#  ('говядина', 'по-дижонски'): 'Food',
#  ('голос', 'солистки'): 'Interior',
#  ('горочо',): 'Food',
#  ('готовили',): 'Service',
#  ('готовиться',): 'Service',
#  ('гранд', '-', 'кафе', '21', 'верста'): 'Whole',
#  ('гребешка',): 'Food',
#  ('грейпфрут',): 'Food',
#  ('гренка',): 'Food',
#  ('гренки',): 'Food',
#  ('грецкие', 'орех'): 'Food',
#  ('гриб',): 'Food',
#  ('гроссенштрасс',): 'Whole',
#  ('грузинский', 'вина'): 'Food',
#  ('грузинский', 'танцевальный', 'коллектив'): 'Interior',
#  ('дамской', 'комната'): 'Interior',
#  ('дать',): 'Whole',
#  ('дать', 'меню'): 'Service',
#  ('дачи',): 'Whole',
#  ('дачу',): 'Whole',
#  ('два', 'палочка'): 'Whole',
#  ('два', 'шоколад'): 'Food',
#  ('два', 'этаж'): 'Interior',
#  ('двух', 'палочка'): 'Whole',
#  ('дорогой',): 'Price',
#  ('доска', 'с', 'мело'): 'Interior',
#  ('дуглас',): 'Whole',
#  ('европейский', 'и', 'японский', 'блюдо'): 'Food',
#  ('закусывая',): 'Food',
#  ('зал', 'для', 'курящих', 'и', 'некурящих'): 'Interior',
#  ('занавески',): 'Interior',
#  ('занавесочка',): 'Interior',
#  ('запеченная',): 'Food',
#  ('запеченной', 'картошка'): 'Food',
#  ('запеченные',): 'Food',
#  ('запеченные', 'суша'): 'Food',
#  ('запеченный', 'сыр'): 'Food',
#  ('запеченох',): 'Food',
#  ('запивать',): 'Food',
#  ('зелень',): 'Food',
#  ('зелень', 'с', 'овощ'): 'Food',
#  ('земляника',): 'Food',
#  ('зона', 'для', 'курящих'): 'Interior',
#  ('зона', 'для', 'некурящих'): 'Interior',
#  ('империю',): 'Whole',
#  ('ингридиент',): 'Food',
#  ('индейка',): 'Food',
#  ('инегридиент',): 'Food',
#  ('интерьер', 'зал'): 'Interior',
#  ('интерьер', 'ресторан'): 'Interior',
#  ('итальянский', 'музыка'): 'Interior',
#  ('итоговый', 'сумма'): 'Price',
#  ('казан', 'кабоб'): 'Food',
#  ('какаоке',): 'Interior',
#  ('кальянном', 'зал'): 'Interior',
#  ('кальянный', 'зал'): 'Interior',
#  ('кальянщик',): 'Service',
#  ('заказываю', 'столик'): 'Service',
#  ('заказывать', 'столик'): 'Service',
#  ('заказывать',): 'Service',
#  ('живая', 'музыка'): 'Interior',
#  ('европейский', 'кухня'): 'Food',
#  ('ели',): 'Food',
#  ('елочка',): 'Interior',
#  ('ель',): 'Food',
#  ('ехать',): 'Food',
#  ('ехать', 'приносить'): 'Service',
#  ('жан-маке',): 'Whole',
#  ('жареный', 'осьминог'): 'Food',
#  ('ждать', 'заказ'): 'Service',
#  ('ждать', 'счет'): 'Service',
#  ('ждем',): 'Service',
#  ('жевать',): 'Food',
#  ('жен-жен',): 'Whole',
#  ('живопись',): 'Interior',
#  ('заказывали',): 'Service',
#  ('жюльен',): 'Food',
#  ('забирать',): 'Service',
#  ('забронировали', 'стол'): 'Service',
#  ('забронировали', 'столик'): 'Service',
#  ('завернуть', 'с', 'себя'): 'Service',
#  ('заказ', 'быть', 'выполнить'): 'Service',
#  ('заказ', 'быть', 'принять'): 'Service',
#  ('заказала', 'столик'): 'Service',
#  ('заказали',): 'Service',
#  ('заказали', 'по', 'купону'): 'Service',
#  ('заказанный', 'заранее'): 'Service',
#  ('заказать', 'обычный', 'столик'): 'Service',
#  ('заказыва', 'стол'): 'Service',
#  ('выражение', 'лицо'): 'Service',
#  ('плова',): 'Food',
#  ('баклажан', 'запеченные'): 'Food',
#  ('банкете',): 'Whole',
#  ('банкетн', 'зал'): 'Interior',
#  ('банкетный', 'зал'): 'Interior',
#  ('бар',): 'Service',
#  ('бара',): 'Service',
#  ('бараний', 'ножка'): 'Food',
#  ('баре',): 'Whole',
#  ('барная', 'карта'): 'Food',
#  ('барная', 'стойка'): 'Interior',
#  ('бекон', 'на', 'хрустяще', 'тосте', 'с', 'помидором', 'черри'): 'Food',
#  ('белый', 'вино'): 'Food',
#  ('береста', 'светлый'): 'Food',
#  ('бесплатно',): 'Price',
#  ('бизнес', '-', 'ланчи'): 'Food',
#  ('бизо', 'с', 'сливками', 'и', 'фрукт'): 'Food',
#  ('билл-хук',): 'Whole',
#  ('блинчик', 'с', 'мясо'): 'Food',
#  ('блюд',): 'Food',
#  ('блюдо', 'восточный', 'кухня'): 'Food',
#  ('блюдо', 'из', 'меню'): 'Food',
#  ('блюдо', 'из', 'мясо'): 'Food',
#  ('блюдо', 'из', 'мясо', 'на', 'мангал'): 'Food',
#  ('блюдо', 'из', 'осьминог'): 'Food',
#  ('блюдо', 'китайский', 'кухня'): 'Food',
#  ('блюдо', 'садж'): 'Food',
#  ('блюдом',): 'Food',
#  ('бокал', 'коньяк'): 'Food',
#  ('бальзамик',): 'Food',
#  ('базилик',): 'Whole',
#  ('выполнение', 'заказ'): 'Service',
#  ('атомосфера',): 'Interior',
#  ('Le', 'glamure'): 'Whole',
#  ('da', 'albertone'): 'Whole',
#  ('legran',): 'Whole',
#  ('tefsi',): 'Whole',
#  ('Америка',): 'Food',
#  ('Америка', 'мак'): 'Food',
#  ('ВИП', 'зона'): 'Interior',
#  ('Маргарита',): 'Food',
#  ('Нельсон', 'пабе'): 'Whole',
#  ('Паста',): 'Food',
#  ('Паста', 'с', 'морепродукт'): 'Food',
#  ('Судак',): 'Food',
#  ('Цезарь', 'с', 'курица'): 'Food',
#  ('Чаплин', '-', 'холл'): 'Whole',
#  ('администрация', 'бара'): 'Service',
#  ('админы',): 'Service',
#  ('аквариум',): 'Interior',
#  ('алкогольных', 'напиток'): 'Food',
#  ('алкоголю',): 'Food',
#  ('альмонд',): 'Food',
#  ('амадеусе',): 'Whole',
#  ('апельсиново', 'сока'): 'Food',
#  ('апрель',): 'Whole',
#  ('асахи',): 'Whole',
#  ('ассортимент',): 'Food',
#  ('ассортимент', 'бара'): 'Food',
#  ('ассортимент', 'блюдо'): 'Food',
#  ('атмосфера', 'заведение'): 'Interior',
#  ('бокал', 'красный', 'сухой', 'вино'): 'Food',
#  ('бокало',): 'Interior',
#  ('большой', 'выбор'): 'Food',
#  ('большой', 'экран'): 'Interior',
#  ('впечатление', 'от', 'посещение'): 'Whole',
#  ('времяпрепровождение',): 'Whole',
#  ('вручило', 'меню'): 'Service',
#  ('встреча',): 'Service',
#  ('встречают',): 'Service',
#  ('второй',): 'Food',
#  ('второй', 'блюдо'): 'Food',
#  ('второй', 'зал'): 'Interior',
#  ('вторы', 'блюдо'): 'Food',
#  ('выбор', 'алкогольных', 'коктейлей'): 'Food',
#  ('выбор', 'вина'): 'Food',
#  ('выбор', 'горячий'): 'Food',
#  ('выбор', 'десерт'): 'Food',
#  ('выбор', 'еда'): 'Food',
#  ('выбор', 'закусок'): 'Food',
#  ('выбор', 'коктейлей'): 'Food',
#  ('выбор', 'по', 'меню', 'и', 'напитка'): 'Food',
#  ('выбор', 'салат'): 'Food',
#  ('выбрать',): 'Service',
#  ('вынести',): 'Service',
#  ('выносили',): 'Service',
#  ('выносить',): 'Service',
#  ('выпекает',): 'Food',
#  ('выпечка',): 'Food',
#  ('выпечки',): 'Food',
#  ('выпивка',): 'Food',
#  ('выпили',): 'Food',
#  ('выпито',): 'Food',
#  ('выпить', 'пиво'): 'Food',
#  ('впечатление', 'остаться'): 'Whole',
#  ('восточный', 'экспресс'): 'Whole',
#  ('внимание',): 'Service',
#  ('васаби',): 'Whole',
#  ('борщ', 'с', 'копченосте'): 'Food',
#  ('бронировали', 'стол'): 'Service',
#  ('бронировали', 'столик'): 'Service',
#  ('бронирование', 'столик'): 'Service',
#  ('бронирование', 'столик', 'по', 'телефон'): 'Service',
#  ('бронировать', 'столик'): 'Service',
#  ('бронь', 'столик'): 'Service',
#  ('буженина', 'на', 'грило'): 'Food',
#  ('булочка',): 'Food',
#  ('бульон', 'с', 'мясо'): 'Food',
#  ('бюджетно',): 'Price',
#  ('вазочка', 'с', 'виноград'): 'Food',
#  ('вайнштефан', 'светлый'): 'Food',
#  ('вежливые',): 'Service',
#  ('внешний', 'вид', 'зал'): 'Interior',
#  ('веранда',): 'Interior',
#  ('вести',): 'Service',
#  ('весь', 'убирать'): 'Service',
#  ('вечер', 'пройти'): 'Whole',
#  ('вид', 'в', 'зал'): 'Interior',
#  ('визит',): 'Whole',
#  ('винишко',): 'Food',
#  ('винная', 'карта'): 'Food',
#  ('вишневый', 'пирог', 'с', 'фисташков', 'кремо'): 'Food',
#  ('вишневый', 'штрудель'): 'Food',
#  ('вишно',): 'Food',
#  ('вкусный',): 'Food',
#  ('владелец',): 'Service',
#  ('камин',): 'Interior',
#  ('капрезе',): 'Food',
#  ('караване', '-', 'сарай'): 'Whole',
#  ('некурящемо', 'зал'): 'Interior',
#  ('нижний', 'зал'): 'Interior',
#  ('обед',): 'Food',
#  ('облицовка', 'стена'): 'Interior',
#  ('обслуга',): 'Service',
#  ('обслуживали',): 'Service',
#  ('обслуживаль',): 'Service',
#  ('обслуживать', 'гость'): 'Service',
#  ('обслуживающая',): 'Service',
#  ('обслужила',): 'Service',
#  ('обстановка', 'ресторан'): 'Interior',
#  ('обтановка',): 'Interior',
#  ('общий', 'оценка', 'ресторану'): 'Whole',
#  ('объедятся',): 'Food',
#  ('овощ', 'с', 'моцарелла'): 'Food',
#  ('овощной', 'гарнир'): 'Food',
#  ('оливки',): 'Food',
#  ('оргазм',): 'Food',
#  ('организовывать',): 'Service',
#  ('основной', 'блюдо'): 'Food',
#  ('основной', 'зал'): 'Interior',
#  ('острый',): 'Food',
#  ('отварный', 'креветки'): 'Food',
#  ('ответить', 'на', 'мой', 'вопрос'): 'Service',
#  ('отвечать',): 'Service',
#  ('отворачивался',): 'Service',
#  ('отделка',): 'Interior',
#  ('отдельный', 'зал'): 'Interior',
#  ('отдохнувший',): 'Whole',
#  ('нести', 'заказ'): 'Service',
#  ('некурящая', 'зона'): 'Interior',
#  ('каракатица',): 'Food',
#  ('недорогое',): 'Price',
#  ('морс', '-', 'из', 'натуральный', 'клюквы'): 'Food',
#  ('мраморно', 'говядин'): 'Food',
#  ('мужчина', 'из', 'гардероб'): 'Service',
#  ('музыкальный', 'коллектив'): 'Interior',
#  ('музыкальный', 'сопровождение'): 'Interior',
#  ('музыкальный', 'фон'): 'Interior',
#  ('мясная', 'нарезка'): 'Food',
#  ('мясное',): 'Food',
#  ('мясное', 'блюдо'): 'Food',
#  ('мясной',): 'Food',
#  ('мясной', 'блюдо'): 'Food',
#  ('мясной', 'стейк'): 'Food',
#  ('мясной', 'чипс', 'из', 'говядина'): 'Food',
#  ('мясо', 'на', 'мангал'): 'Food',
#  ('на', 'вкус'): 'Food',
#  ('набор', 'блюдо'): 'Food',
#  ('накладывали',): 'Service',
#  ('накопительно', 'скидку'): 'Service',
#  ('накормили',): 'Food',
#  ('накрыть', 'стол'): 'Service',
#  ('напоили',): 'Food',
#  ('народ', 'быть', 'не', 'очень', 'много'): 'Interior',
#  ('настойка',): 'Food',
#  ('настроение',): 'Whole',
#  ('начинка',): 'Food',
#  ('не', '"', 'обслуживали', '"'): 'Service',
#  ('не', 'курящий', 'зал'): 'Interior',
#  ('небо',): 'Whole',
#  ('невский', '166'): 'Whole',
#  ('отдохнуть',): 'Whole',
#  ('открытый', 'кухня'): 'Interior',
#  ('открыть',): 'Service',
#  ('открыть', 'дверь'): 'Service',
#  ('патио', 'на', 'невском'): 'Whole',
#  ('паэлью', 'с', 'курица', 'и', 'кролик'): 'Food',
#  ('пенно', '4', 'сыр'): 'Food',
#  ('первый', 'зал'): 'Interior',
#  ('перепробовали',): 'Food',
#  ('пересесть',): 'Service',
#  ('перечный', 'стейк'): 'Food',
#  ('перчики', 'халапен'): 'Food',
#  ('песня',): 'Interior',
#  ...}

# %%
best_mention_sentiment = get_mention_category(train_asp, 'sentiment')

# %%
best_mention_sentiment
# Out:
# {('интерьер',): 'positive',
#  ('обслуживание',): 'positive',
#  ('ресторан',): 'positive',
#  ('место',): 'positive',
#  ('кухня',): 'positive',
#  ('официант',): 'positive',
#  ('заведение',): 'positive',
#  ('персонал',): 'positive',
#  ('еда',): 'positive',
#  ('цена',): 'positive',
#  ('блюдо',): 'positive',
#  ('атмосфера',): 'positive',
#  ('порция',): 'positive',
#  ('музыка',): 'positive',
#  ('пиво',): 'positive',
#  ('меню',): 'positive',
#  ('встретить',): 'positive',
#  ('обстановка',): 'positive',
#  ('официантка',): 'positive',
#  ('вечер',): 'positive',
#  ('девушка',): 'positive',
#  ('администратор',): 'positive',
#  ('зал',): 'positive',
#  ('горячий',): 'neutral',
#  ('обслуживал',): 'positive',
#  ('сервис',): 'positive',
#  ('десерт',): 'positive',
#  ('ждать',): 'negative',
#  ('салаты',): 'positive',
#  ('поесть',): 'positive',
#  ('столик',): 'positive',
#  ('живой', 'музыка'): 'positive',
#  ('напиток',): 'neutral',
#  ('молодой', 'человек'): 'positive',
#  ('провести', 'время'): 'positive',
#  ('вкус',): 'positive',
#  ('закуска',): 'positive',
#  ('шашлык',): 'positive',
#  ('мясо',): 'positive',
#  ('стол',): 'positive',
#  ('салат',): 'positive',
#  ('кафе',): 'positive',
#  ('диваны',): 'positive',
#  ('заказ',): 'positive',
#  ('чай',): 'neutral',
#  ('вино',): 'positive',
#  ('приготовлено',): 'positive',
#  ('заказать',): 'neutral',
#  ('рассказать',): 'positive',
#  ('предложить',): 'positive',
#  ('праздник',): 'positive',
#  ('заказать', 'столик'): 'neutral',
#  ('ребята',): 'positive',
#  ('заказ', 'принять'): 'positive',
#  ('паб',): 'positive',
#  ('поужинать',): 'neutral',
#  ('проводить',): 'positive',
#  ('готовить',): 'positive',
#  ('детский', 'комната'): 'positive',
#  ('пообедать',): 'neutral',
#  ('десерта',): 'positive',
#  ('ресторану',): 'positive',
#  ('кофе',): 'neutral',
#  ('человек',): 'positive',
#  ('принести', 'меню'): 'positive',
#  ('принести',): 'positive',
#  ('ресторанчик',): 'neutral',
#  ('кальян',): 'positive',
#  ('пасту',): 'neutral',
#  ('рыба',): 'positive',
#  ('счет',): 'neutral',
#  ('съесть',): 'neutral',
#  ('морс',): 'neutral',
#  ('напитка',): 'neutral',
#  ('пицца',): 'neutral',
#  ('свеча',): 'positive',
#  ('свет',): 'positive',
#  ('суп',): 'positive',
#  ('пробовать',): 'positive',
#  ('администрация',): 'positive',
#  ('диванчик',): 'positive',
#  ('шеф', '-', 'повару'): 'positive',
#  ('свинина',): 'positive',
#  ('встречать',): 'positive',
#  ('диванчики',): 'positive',
#  ('ужин',): 'positive',
#  ('работать',): 'positive',
#  ('гардеробщик',): 'positive',
#  ('мороженое',): 'positive',
#  ('оформлено',): 'positive',
#  ('покушать',): 'neutral',
#  ('вид', 'из', 'окно'): 'positive',
#  ('официантки',): 'positive',
#  ('помочь',): 'positive',
#  ('советовать',): 'positive',
#  ('соус',): 'negative',
#  ('паста',): 'positive',
#  ('блюда',): 'neutral',
#  ('поварам',): 'positive',
#  ('стейки',): 'positive',
#  ('скидка',): 'positive',
#  ('хлеб',): 'positive',
#  ('обслуживать', 'персонал'): 'positive',
#  ('столик', 'заказать'): 'neutral',
#  ('повар',): 'negative',
#  ('бармен',): 'positive',
#  ('торт',): 'positive',
#  ('выпить',): 'neutral',
#  ('овощ',): 'positive',
#  ('провожать',): 'positive',
#  ('стул',): 'negative',
#  ('гардероб',): 'positive',
#  ('алкоголь',): 'neutral',
#  ('второй', 'этаж'): 'positive',
#  ('десерты',): 'positive',
#  ('перекусить',): 'neutral',
#  ('горячий', 'блюдо'): 'positive',
#  ('подходить',): 'positive',
#  ('мебель',): 'positive',
#  ('оформлен',): 'positive',
#  ('сотрудник',): 'positive',
#  ('впечатление',): 'positive',
#  ('супчики',): 'positive',
#  ('скидку',): 'positive',
#  ('готовят',): 'positive',
#  ('роллы',): 'positive',
#  ('улыбаться',): 'positive',
#  ('заказ', 'принести'): 'positive',
#  ('управляющий',): 'negative',
#  ('коктейли',): 'positive',
#  ('приносить',): 'negative',
#  ('суша',): 'negative',
#  ('проводить', 'к', 'столику'): 'positive',
#  ('детский', 'меню'): 'positive',
#  ('десерт', 'тирамису'): 'positive',
#  ('провести', 'вечер'): 'positive',
#  ('проводить', 'до', 'столик'): 'positive',
#  ('японский', 'кухня'): 'positive',
#  ('продукт',): 'positive',
#  ('манго',): 'positive',
#  ('местечко',): 'positive',
#  ('сервировка',): 'positive',
#  ('каминный', 'зал'): 'positive',
#  ('менеджер',): 'positive',
#  ('масло',): 'positive',
#  ('салями',): 'neutral',
#  ('место', 'для', 'танец'): 'positive',
#  ('китайский', 'кухня'): 'positive',
#  ('коктейль',): 'positive',
#  ('рис',): 'negative',
#  ('концерт',): 'neutral',
#  ('рояль',): 'positive',
#  ('кушаль',): 'positive',
#  ('кухне',): 'positive',
#  ('салат', '"', 'Цезарь', '"'): 'positive',
#  ('итальянский', 'ресторан'): 'positive',
#  ('мужчина',): 'positive',
#  ('наелась',): 'positive',
#  ('набережную',): 'positive',
#  ('есть',): 'positive',
#  ('публика',): 'positive',
#  ('заведением',): 'positive',
#  ('заказали', 'столик'): 'neutral',
#  ('стейк',): 'neutral',
#  ('рассказывать',): 'positive',
#  ('соуса',): 'negative',
#  ('закусок',): 'positive',
#  ('девушка', 'официантка'): 'positive',
#  ('зал', 'для', 'курящих'): 'neutral',
#  ('зал', 'для', 'некурящих'): 'positive',
#  ('соотношение', 'цена/качество'): 'positive',
#  ('сок',): 'positive',
#  ('здороваются',): 'positive',
#  ('няня',): 'positive',
#  ('сажать',): 'positive',
#  ('отдохнули',): 'positive',
#  ('шампанское',): 'positive',
#  ('блин',): 'neutral',
#  ('выбор', 'алкоголь'): 'positive',
#  ('подача',): 'positive',
#  ('выбор', 'блюдо'): 'negative',
#  ('фрукт',): 'negative',
#  ('первый', 'этаж'): 'neutral',
#  ('убирать',): 'positive',
#  ('отдать',): 'positive',
#  ('первый', 'блюдо'): 'neutral',
#  ('выбор', 'пиво'): 'positive',
#  ('хачапури',): 'positive',
#  ('бронировать', 'стол'): 'neutral',
#  ('подушка',): 'positive',
#  ('арагви',): 'positive',
#  ('подача', 'блюдо'): 'positive',
#  ('персонал', 'ресторан'): 'positive',
#  ('чек',): 'positive',
#  ('водка',): 'positive',
#  ('баклажан',): 'positive',
#  ('вкус', 'блюдо'): 'positive',
#  ('филадельфия',): 'positive',
#  ('виски',): 'neutral',
#  ('посещение',): 'positive',
#  ('устрица',): 'neutral',
#  ('попить',): 'positive',
#  ('посоветуют',): 'positive',
#  ('отношение',): 'positive',
#  ('чебурек',): 'positive',
#  ('уносят',): 'positive',
#  ('улыбаются',): 'positive',
#  ('бара',): 'positive',
#  ('вентиляция',): 'positive',
#  ('посуда',): 'positive',
#  ('освещение',): 'positive',
#  ('говядина',): 'positive',
#  ('приготовленный',): 'positive',
#  ('телятины',): 'positive',
#  ('обстановка', 'в', 'ресторан'): 'positive',
#  ('гость',): 'negative',
#  ('пить',): 'neutral',
#  ('обслужили',): 'positive',
#  ('Нельсон', 'паб'): 'positive',
#  ('обслуживающем', 'персонал'): 'positive',
#  ('тарелка',): 'positive',
#  ('танцпол',): 'positive',
#  ('тан', 'жен'): 'positive',
#  ('бизнес', '-', 'ленч'): 'neutral',
#  ('цезарь', 'с', 'креветками'): 'positive',
#  ('принять', 'заказ'): 'positive',
#  ('обедать',): 'positive',
#  ('помогли',): 'positive',
#  ('панакота',): 'positive',
#  ('вкусно',): 'positive',
#  ('прибор',): 'positive',
#  ('тирамису',): 'neutral',
#  ('чаевые',): 'negative',
#  ('помещение',): 'positive',
#  ('палочка',): 'negative',
#  ('шеф', '-', 'повар'): 'positive',
#  ('холодный', 'закуска'): 'positive',
#  ('Токио',): 'positive',
#  ('блюдох',): 'neutral',
#  ('подать',): 'positive',
#  ('ресторан', '"', 'русский', 'китч', '"'): 'positive',
#  ('ресторан', '"', 'фаворит', '"'): 'neutral',
#  ('ресторан', 'кухню'): 'neutral',
#  ('подойти',): 'neutral',
#  ('ресторан', '"', 'долина', '"'): 'neutral',
#  ('ресторан', 'китайский', 'кухня'): 'neutral',
#  ('подсказать',): 'positive',
#  ('ресторан', '"', 'эскалибур', '"'): 'neutral',
#  ('ресторан', 'italy'): 'positive',
#  ('подскажет',): 'positive',
#  ('ресторан', 'гламур'): 'neutral',
#  ('подскажут',): 'positive',
#  ('ресторан', '"', 'крапива', '"'): 'neutral',
#  ('ресторан', '"', 'мамалыга', '"'): 'positive',
#  ('ресторан', 'аллегро'): 'neutral',
#  ('принёс', 'меню'): 'positive',
#  ('ресторан', 'марчеллис'): 'neutral',
#  ('ролл', 'филадельфия'): 'neutral',
#  ('роллы', 'без', 'рис'): 'positive',
#  ('роллы', 'запеченные', 'на', 'уголь'): 'positive',
#  ('роллы', 'на', 'грило'): 'positive',
#  ('руккола', 'с', 'креветками'): 'neutral',
#  ('руководство', 'ресторан'): 'positive',
#  ('подарок', 'от', 'шеф-повар'): 'positive',
#  ('рулет', 'из', 'лосося', 'с', 'зелено', 'спаржай'): 'neutral',
#  ('подавать',): 'positive',
#  ('подавались',): 'positive',
#  ('поворам',): 'positive',
#  ('повара',): 'positive',
#  ('рулетики', 'из', 'баклажан'): 'positive',
#  ('рулетики', 'с', 'гриб'): 'positive',
#  ('площадь', 'ресторан'): 'negative',
#  ('плова',): 'neutral',
#  ('плетеным', 'гамак'): 'positive',
#  ('платить',): 'neutral',
#  ('рыба', '-', 'стейк', 'из', 'форель'): 'positive',
#  ('рыбка',): 'neutral',
#  ('ролл',): 'neutral',
#  ('ресторан', 'мисо'): 'positive',
#  ('рис', 'с', 'курица'): 'positive',
#  ('ресторан', 'на', 'приморской'): 'negative',
#  ('ресторан', 'палкин'): 'positive',
#  ('ресторан', 'трес', 'амигос'): 'positive',
#  ('ресторан', 'харбин', 'на', 'академическая'): 'neutral',
#  ('ресторан', 'харбин', 'на', 'приморской'): 'both',
#  ('подождать',): 'neutral',
#  ('подготовить', 'закуска'): 'positive',
#  ('подача', 'мясо'): 'positive',
#  ('ресторану', 'La', 'fabrik'): 'positive',
#  ('ресторанчике',): 'negative',
#  ('рибай',): 'positive',
#  ('ризотто',): 'positive',
#  ('ризотто', 'с', 'белый', 'гриб'): 'neutral',
#  ('ризотто', 'с', 'спраж', 'и', 'горгонзолой'): 'neutral',
#  ('подать', 'меню'): 'positive',
#  ('пожарские', 'котлета'): 'positive',
#  ('попили',): 'positive',
#  ('поиинтересовался',): 'positive',
#  ('прожарка',): 'positive',
#  ('программа',): 'positive',
#  ('продегустировать',): 'neutral',
#  ('предупредить',): 'positive',
#  ('предоставить',): 'positive',
#  ('предложить', 'сесть'): 'positive',
#  ('предложить', 'присесть'): 'positive',
#  ('прожаренное',): 'positive',
#  ('предложить', 'напиток'): 'neutral',
#  ('предложить', 'меню'): 'neutral',
#  ('предложили',): 'positive',
#  ('пустой', 'помещение'): 'both',
#  ('пролил',): 'negative',
#  ('предлагать', 'пробовать'): 'positive',
#  ('предлагать',): 'positive',
#  ('предварительный', 'резервация'): 'neutral',
#  ('появляться',): 'positive',
#  ('появиться',): 'positive',
#  ('пространство',): 'positive',
#  ('профессионал',): 'positive',
#  ('прощаются',): 'positive',
#  ('предупрежден',): 'positive',
#  ('приветливая',): 'positive',
#  ('провожает', 'к', 'стол'): 'positive',
#  ('приглашать',): 'positive',
#  ('приправлен',): 'negative',
#  ('приносили',): 'positive',
#  ('проведенным', 'вечер'): 'positive',
#  ('принести', 'специи'): 'positive',
#  ('принесли',): 'positive',
#  ('прием',): 'positive',
#  ('провести', 'до', 'столик'): 'positive',
#  ('провести', 'там', 'время'): 'positive',
#  ('проводили',): 'positive',
#  ('проводить', 'до', 'место'): 'neutral',
#  ('проводить', 'до', 'наш', 'столик'): 'neutral',
#  ('приготовленное',): 'positive',
#  ('проводить', 'за', 'столик'): 'positive',
#  ('проводить', 'к', 'стол'): 'neutral',
#  ('приготовление',): 'neutral',
#  ('приготовлен',): 'positive',
#  ('поужиналь',): 'positive',
#  ('пшеничное', 'и', 'ячменное', 'пиво'): 'positive',
#  ('показать',): 'positive',
#  ('помогли', 'с', 'заказом'): 'positive',
#  ('разнообразие',): 'positive',
#  ('разнообразие', 'в', 'меню'): 'positive',
#  ('разрешать',): 'positive',
#  ('приправ',): 'negative',
#  ('расплачиваться', 'по', 'счет'): 'negative',
#  ('расположенный',): 'positive',
#  ('пообедали',): 'positive',
#  ('помочь', 'с', 'выбор'): 'positive',
#  ('расположиться',): 'positive',
#  ('потанцевать',): 'positive',
#  ('результат', 'вместе', 'с', 'чаевыми'): 'neutral',
#  ('помидор',): 'positive',
#  ('полусухое',): 'positive',
#  ('полумрак',): 'positive',
#  ('поленте',): 'positive',
#  ('пол', 'порция'): 'neutral',
#  ('показывать',): 'positive',
#  ('ресторан', '"', 'Оливье', '"'): 'neutral',
#  ('попрощаться',): 'negative',
#  ('порекомендовал',): 'positive',
#  ('пюре',): 'both',
#  ('потанцевали',): 'positive',
#  ('работа',): 'positive',
#  ('работа', 'она', 'выполнял'): 'positive',
#  ('постное', 'меню'): 'both',
#  ('посоветует',): 'positive',
#  ('послевкусие',): 'positive',
#  ('посетитель', 'ВИП', '-', 'зал'): 'negative',
#  ('рагу',): 'positive',
#  ('радио',): 'positive',
#  ('порция', 'салат'): 'positive',
#  ('развлекательная', 'программа'): 'positive',
#  ('раздель', '-', 'проводить'): 'positive',
#  ('разливал', 'шампанское'): 'negative',
#  ('разложить', 'прибор'): 'positive',
#  ('размер', 'порций'): 'positive',
#  ('размер', 'порция'): 'positive',
#  ('скорость',): 'positive',
#  ('сажать', 'за', 'столик'): 'positive',
#  ('ужинали',): 'positive',
#  ('утинуй', 'грудка', 'гриль', 'с', 'фрукт'): 'positive',
#  ('усадиль',): 'positive',
#  ('упаковано',): 'positive',
#  ('упакована',): 'positive',
#  ('улитка',): 'positive',
#  ('украшение', 'зал'): 'positive',
#  ('ужинал',): 'positive',
#  ('туалет', 'с', 'аквариумами'): 'positive',
#  ('угощение',): 'positive',
#  ('уголок',): 'positive',
#  ('убираются',): 'negative',
#  ('убиралась',): 'positive',
#  ('тыквенный', 'суп'): 'positive',
#  ('тушеная', 'телятина'): 'positive',
#  ('тунцом',): 'positive',
#  ('утка',): 'negative',
#  ('утка', 'в', 'апельсинов', 'соусе'): 'positive',
#  ('утка', 'по-пекинский'): 'neutral',
#  ('французский', 'красный', 'сухой', 'вино'): 'positive',
#  ('фотан',): 'positive',
#  ('форель', ',', 'запеченная', 'с', 'овощ'): 'positive',
#  ('фонтан', 'в', 'центр', 'зал'): 'negative',
#  ('фонарик',): 'positive',
#  ('фокачча', 'с', 'прованский', 'трава', 'и', 'сыр', 'пармезан'): 'neutral',
#  ('фиш', '&о', 'чипс'): 'positive',
#  ('фирменное', 'блюдо'): 'positive',
#  ('филки', 'норвежское', 'лосося', 'с', 'овощ', 'и', 'креветками'): 'positive',
#  ('уютный',): 'positive',
#  ('уютно',): 'positive',
#  ('уют',): 'positive',
#  ('уходить',): 'negative',
#  ('ухо',): 'positive',
#  ('тунец', 'с', 'овощ', 'гриль'): 'neutral',
#  ('туалет',): 'neutral',
#  ('саксофонист',): 'positive',
#  ('танец',): 'positive',
#  ('твинс',): 'positive',
#  ('тарелку', 'к', 'пиву'): 'neutral',
#  ('тарелка', 'фрукт'): 'positive',
#  ('тарелка', 'убирать'): 'positive',
#  ('тарелка', 'к', 'пиву'): 'neutral',
#  ('танцы',): 'positive',
#  ('тан', 'жена'): 'both',
#  ('трес', 'амигос'): 'positive',
#  ('тамаду',): 'neutral',
#  ('сытый', 'хавронья', 'из', 'свинина'): 'positive',
#  ('сырныйи', 'шарик'): 'negative',
#  ('сырные', 'шарик'): 'neutral',
#  ('сырные', 'палочка'): 'neutral',
#  ('сырной', 'тарелка'): 'neutral',
#  ('телевизор',): 'positive',
#  ('телятина',): 'positive',
#  ('теплый', 'мексиканским', 'салат'): 'positive',
#  ('террас',): 'positive',
#  ('тревелс',): 'positive',
#  ('трапеза', 'итальянский', 'кухня'): 'positive',
#  ('торты',): 'positive',
#  ('тортом',): 'positive',
#  ('тортик',): 'positive',
#  ('томатный', 'суп'): 'neutral',
#  ('томатный', 'соус'): 'positive',
#  ('томатный', 'пасту'): 'negative',
#  ('тираму',): 'positive',
#  ('тимьян',): 'positive',
#  ('тесто',): 'positive',
#  ('тест',): 'negative',
#  ('тертым', 'сыр'): 'neutral',
#  ('террасу',): 'neutral',
#  ('франческо',): 'positive',
#  ('фроузен', 'парфе'): 'positive',
#  ('чукка', 'салат'): 'neutral',
#  ('шашлык', 'из', 'баранина', 'на', 'кость', 'и', 'мякоть'): 'neutral',
#  ('шавермы',): 'negative',
#  ('шаверму', 'с', 'курица'): 'negative',
#  ('чистота', 'скатерт'): 'both',
#  ('фуа', '-', 'грой'): 'positive',
#  ('чипсы',): 'positive',
#  ('человек', 'из', 'персонал'): 'positive',
#  ('чебуреки', 'с', 'сыр', 'сулугуни', 'и', 'зелень'): 'positive',
#  ('чебуреки',): 'positive',
#  ('шашлык', 'из', 'куриной', 'грудки'): 'positive',
#  ('шашлык', 'из', 'курицы'): 'positive',
#  ('шашлык', 'ягненка'): 'positive',
#  ('шашлыка', 'из', 'лосося'): 'negative',
#  ('яблочный', 'пирог'): 'positive',
#  ('эспрессо',): 'neutral',
#  ('шурвы',): 'neutral',
#  ('шторы',): 'negative',
#  ('шпинат',
#   'с',
#   'голубой',
#   'сыр',
#   'под',
#   'фантастический',
#   'заправкой'): 'positive',
#  ('шоу',): 'positive',
#  ('шоколадный', 'фонтан'): 'positive',
#  ('шоколадная', 'шкатулка'): 'positive',
#  ('шницель',): 'positive',
#  ('шеф-повар', 'ресторан'): 'neutral',
#  ('шеф-повар',): 'positive',
#  ('шеф', 'повару'): 'positive',
#  ('шеф', 'повара'): 'positive',
#  ('шеф', '-', 'повара'): 'positive',
#  ('чебурека',): 'neutral',
#  ('чай', 'с', 'чабрец'): 'positive',
#  ('хочухарчо',): 'neutral',
#  ('хостес',): 'negative',
#  ('холодный', 'рыбный', 'рулет'): 'positive',
#  ('холодный', 'закусок'): 'positive',
#  ('холодный', 'закуск'): 'neutral',
#  ('хозяин',): 'positive',
#  ('хлебный', 'тарелка'): 'positive',
#  ('хлебный', 'корзина'): 'positive',
#  ('хлебный', 'греночки', 'с', 'сыр'): 'positive',
#  ('хлебно', 'козинка'): 'neutral',
#  ('хинкали',): 'positive',
#  ('харбина', 'на', 'приморской'): 'negative',
#  ('харбин', 'на', 'приморской'): 'negative',
#  ('хостесс',): 'positive',
#  ('цвет',): 'positive',
#  ('чай', 'с', 'лимон', 'и', 'чабрец'): 'neutral',
#  ('цветочный', 'композиция'): 'neutral',
#  ('чай', 'с', 'десерт'): 'neutral',
#  ('чай', 'по', 'восточный', 'с', 'инжирной', 'варенье'): 'positive',
#  ('чаек',): 'positive',
#  ('центр', 'зал'): 'negative',
#  ('ценовой', 'категория'): 'neutral',
#  ('ценник',): 'negative',
#  ('цена', 'на', 'кальян'): 'negative',
#  ('цена', 'на', 'вино'): 'negative',
#  ('цезарь', 'с', 'лососем'): 'positive',
#  ('цезарь',): 'neutral',
#  ('цезар',): 'negative',
#  ('сырная', 'тарелка'): 'negative',
#  ('сырная', 'и', 'мясная', 'тарелка'): 'positive',
#  ('сыр', 'филадельфия'): 'positive',
#  ('светильники', '/', 'люстра'): 'neutral',
#  ('свиную', 'рульку'): 'negative',
#  ('свинина',
#   'с',
#   'сыр',
#   'фета',
#   ',',
#   'фисташка',
#   'и',
#   'грибно',
#   'соус'): 'positive',
#  ('свинина', 'с', 'гриб'): 'positive',
#  ('свинина', 'по-пекинский'): 'neutral',
#  ('свинина', 'в', 'кисло-сладком', 'соусе'): 'neutral',
#  ('свечи-', 'цветы'): 'positive',
#  ('светлый', 'зал'): 'positive',
#  ('смотреть', 'за', 'стол'): 'positive',
#  ('свежий', 'овощ'): 'neutral',
#  ('свежий',): 'neutral',
#  ('сашими',): 'positive',
#  ('сациви', 'из', 'баклажан'): 'positive',
#  ('санторини',): 'positive',
#  ('санам',): 'neutral',
#  ('свободный', 'место'): 'negative',
#  ('свободный', 'столик'): 'both',
#  ('сдача',): 'negative',
#  ('слушать',): 'negative',
#  ('следить', 'за', 'стол'): 'positive',
#  ('сладости',): 'neutral',
#  ('скульптур',): 'positive',
#  ('планета', 'суши'): 'positive',
#  ('скиснуть',): 'negative',
#  ('скатерти', 'на', 'стол'): 'negative',
#  ('сервируют',): 'positive',
#  ('сервировку', 'блюдо'): 'positive',
#  ('сельдь', 'под', 'шуба', '…', 'с', 'краб'): 'neutral',
#  ('селедка',): 'positive',
#  ('сдача', 'ждать'): 'negative',
#  ('салаты', 'из', 'язык', 'и', 'морепродукт'): 'neutral',
#  ('салаты', '(', 'с', 'лососем', ',', 'краб', ',', 'тунцом', ')'): 'positive',
#  ('салат', 'с', 'креветками'): 'positive',
#  ('салат', 'пампелон'): 'positive',
#  ('салат', 'из', 'тунца'): 'neutral',
#  ('салат', 'из', 'свиной', 'ухо'): 'positive',
#  ('салат',
#   'из',
#   'они',
#   'меню',
#   'с',
#   '"',
#   'семга',
#   'горячий',
#   'копчение',
#   '"'): 'positive',
#  ('салат', 'из', 'морепродукт'): 'positive',
#  ('салат', 'из', 'лосося'): 'positive',
#  ('салат', 'из', 'лисичек', 'с', 'кроличья', 'печенью'): 'neutral',
#  ('салат', 'из', 'запеченох', 'овощ'): 'positive',
#  ('салат', 'грибной'): 'positive',
#  ('салат', 'греческий'): 'negative',
#  ('салат', 'Цезарь'): 'negative',
#  ('салат', '"', 'салмон', '"', 'с', 'лососем'): 'both',
#  ('салат', '"', 'розана', '"'): 'positive',
#  ('салат', '"', 'лагуна', '"'): 'positive',
#  ('салат', '"', 'кавказский', '"'): 'positive',
#  ('салат', 'с', 'домашний', 'сыр'): 'neutral',
#  ('салат', 'с', 'креветками', 'и', 'краб'): 'negative',
#  ('салаты', '"', 'Цезарь', '"'): 'positive',
#  ('салат', 'с', 'креветками', 'и', 'лист'): 'positive',
#  ('салату', 'цезарь'): 'neutral',
#  ('салатики',): 'neutral',
#  ('салатик', '"', 'Оливье', '"'): 'neutral',
#  ('салатик',): 'neutral',
#  ('салатама',): 'positive',
#  ('салат', 'цезарь', 'с', 'креветками'): 'positive',
#  ('салат', 'цезарь'): 'positive',
#  ('салат', 'с', 'угрем'): 'positive',
#  ('салат', 'с', 'рыба'): 'positive',
#  ('салат', 'с', 'рукколой', 'и', 'вяленоми', 'помидор'): 'neutral',
#  ('салат', 'с', 'малосольное', 'лососем'): 'positive',
#  ('салат', 'с', 'куриной', 'печенью'): 'positive',
#  ('смотреть', 'за', 'посетитель'): 'positive',
#  ('смузи', 'злаковый'): 'neutral',
#  ('сыр',): 'positive',
#  ('стрейк', 'Нью-Йорк'): 'positive',
#  ('суп', 'из', 'печеного', 'чеснок'): 'positive',
#  ('судака', 'фаршированный'): 'positive',
#  ('судака',): 'neutral',
#  ('стульчики', 'для', 'кормление'): 'positive',
#  ('столовая',): 'negative',
#  ('смузи', 'овощной'): 'neutral',
#  ('столика',): 'positive',
#  ('столик', 'не', 'заказывать'): 'neutral',
#  ('столик', 'забронировали'): 'neutral',
#  ('столик', 'бронировать'): 'positive',
#  ('столик', 'бронировали'): 'neutral',
#  ('суп', 'с', 'норвежским', 'лососем'): 'neutral',
#  ('суп', 'чанахи'): 'positive',
#  ('суп-вино',): 'neutral',
#  ('суп-пюра', 'из', 'белый', 'гриб'): 'positive',
#  ('съела',): 'neutral',
#  ('счёт',): 'neutral',
#  ('счет', 'мы', 'принести'): 'positive',
#  ('счесть',): 'negative',
#  ('сушки', 'с', 'перчиком'): 'positive',
#  ('суши',): 'positive',
#  ('суша', '-', 'бар'): 'positive',
#  ('сухарик',): 'negative',
#  ('супчик',): 'positive',
#  ('супами',): 'positive',
#  ('суп-харчо',): 'positive',
#  ('стол', 'забронировали'): 'neutral',
#  ('стол', 'для', 'рисование'): 'positive',
#  ('стоимость', 'ужин'): 'negative',
#  ('спагетть',): 'positive',
#  ('соус', 'к', 'мясо', 'и', 'картофелю'): 'neutral',
#  ('соус', 'из', 'петрушка'): 'positive',
#  ('соус', 'без', 'анчоусов'): 'neutral',
#  ('сотрудник', 'ресторан'): 'positive',
#  ('состав', 'десерта'): 'neutral',
#  ('состав', 'блюдо'): 'negative',
#  ('сорбет',): 'neutral',
#  ('сорба',): 'positive',
#  ('соотношение', 'цена', 'и', 'качество'): 'positive',
#  ('соленый', 'гриб'): 'negative',
#  ('соленый',): 'negative',
#  ('совет', 'по', 'меню'): 'positive',
#  ('совет',): 'positive',
#  ('собрать',): 'positive',
#  ('собеседник',): 'positive',
#  ('соус', 'тар-тар'): 'positive',
#  ('спагетть', 'карбонара'): 'neutral',
#  ('стена',): 'negative',
#  ('спагетть', 'с', 'фрикаделька'): 'positive',
#  ('стейку',): 'positive',
#  ('стейком',): 'positive',
#  ('стейк-', 'хаусах'): 'negative',
#  ('стейк', 'с', 'соус', 'из', 'белый', 'гриб'): 'positive',
#  ('стейк', 'рибай'): 'positive',
#  ('стейк', 'из', 'тунца'): 'positive',
#  ('стейк', 'из', 'мраморный', 'говядина'): 'both',
#  ('стейк', 'из', 'лосося'): 'positive',
#  ('стейк', 'из', 'говядина', 'с', 'шпинат'): 'positive',
#  ('стандартный', 'блюдо'): 'neutral',
#  ('спрашивать',): 'positive',
#  ('спокойный',): 'positive',
#  ('спиртной', 'напитка'): 'positive',
#  ('плата',): 'negative',
#  ('1ом', 'этаж'): 'negative',
#  ('плазменный', 'панель'): 'positive',
#  ('декором',): 'positive',
#  ('десертик',): 'positive',
#  ('десерт', '"', 'три', 'шоколад', '"'): 'positive',
#  ('депозит', '5', 'тысяча'): 'positive',
#  ('деньги',): 'positive',
#  ('делфим', 'Бар'): 'positive',
#  ('деликатес',): 'neutral',
#  ('делать', 'заказ'): 'positive',
#  ('декор',): 'positive',
#  ('девочки', '-', 'официантки'): 'positive',
#  ('девченки',): 'positive',
#  ('девушка', 'официантки'): 'positive',
#  ('девушка', 'официант'): 'positive',
#  ('девушка', 'администратор'): 'positive',
#  ('девушка', '-', 'певица'): 'positive',
#  ('девушка', '-', 'официантки'): 'positive',
#  ('девушка', '-', 'администратор'): 'positive',
#  ('диванах',): 'positive',
#  ('диваном',): 'positive',
#  ('диванчики', '-', 'купе'): 'positive',
#  ('дораду', 'с', 'овощ'): 'positive',
#  ('допинг',): 'negative',
#  ('домашний', 'морс'): 'positive',
#  ('домашний', 'мороженое'): 'positive',
#  ('домашний', 'лимонады'): 'positive',
#  ('домашний', 'куриный', 'супчик'): 'positive',
#  ('доедаль',): 'positive',
#  ('добавлять', 'вино'): 'positive',
#  ('дитае',): 'neutral',
#  ('дисконтно', 'карта'): 'positive',
#  ('директор',): 'positive',
#  ('дизайнерское', 'решение'): 'positive',
#  ('дизайн',): 'positive',
#  ('девушка', '(', 'официант', ')'): 'neutral',
#  ('девочка', '-', 'официант'): 'positive',
#  ('выпито',): 'neutral',
#  ('глобуса',): 'negative',
#  ('готовиться',): 'negative',
#  ('готовили',): 'negative',
#  ('горочо',): 'positive',
#  ('голос', 'солистки'): 'positive',
#  ('говядина', 'по-дижонски'): 'positive',
#  ('говядин',): 'positive',
#  ('главный', 'зал'): 'negative',
#  ('двух', 'палочка'): 'positive',
#  ('гарнир',): 'positive',
#  ('выслушала',): 'positive',
#  ('выражение', 'лицо'): 'negative',
#  ('выполнение', 'заказ'): 'positive',
#  ('гранд', '-', 'кафе', '21', 'верста'): 'positive',
#  ('гребешка',): 'positive',
#  ('грейпфрут',): 'positive',
#  ('два', 'этаж'): 'neutral',
#  ('два', 'шоколад'): 'positive',
#  ('два', 'палочка'): 'positive',
#  ('дачу',): 'neutral',
#  ('дачи',): 'neutral',
#  ('дать', 'меню'): 'positive',
#  ('дать',): 'both',
#  ('дамской', 'комната'): 'negative',
#  ('грузинский', 'танцевальный', 'коллектив'): 'positive',
#  ('грузинский', 'вина'): 'negative',
#  ('гроссенштрасс',): 'positive',
#  ('гриб',): 'positive',
#  ('грецкие', 'орех'): 'positive',
#  ('гренки',): 'neutral',
#  ('гренка',): 'positive',
#  ('дорогой',): 'negative',
#  ('доска', 'с', 'мело'): 'positive',
#  ('дуглас',): 'neutral',
#  ('занавески',): 'positive',
#  ('запеченох',): 'neutral',
#  ('запеченный', 'сыр'): 'negative',
#  ('запеченные', 'суша'): 'positive',
#  ('запеченные',): 'neutral',
#  ('запеченной', 'картошка'): 'positive',
#  ('запеченная',): 'positive',
#  ('занавесочка',): 'positive',
#  ('залы',): 'positive',
#  ('европейский', 'и', 'японский', 'блюдо'): 'positive',
#  ('зал', 'для', 'курящих', 'и', 'некурящих'): 'positive',
#  ('закусывая',): 'positive',
#  ('запивать',): 'positive',
#  ('зелень',): 'neutral',
#  ('зелень', 'с', 'овощ'): 'positive',
#  ('земляника',): 'positive',
#  ('итальянский', 'музыка'): 'positive',
#  ('итальянский', 'кухня'): 'positive',
#  ('итальянский', 'блюдо'): 'positive',
#  ('интерьер', 'ресторан'): 'positive',
#  ('интерьер', 'зал'): 'positive',
#  ('инегридиент',): 'negative',
#  ('индейка',): 'neutral',
#  ('ингридиент',): 'neutral',
#  ('империю',): 'positive',
#  ('зона', 'для', 'некурящих'): 'positive',
#  ('зона', 'для', 'курящих'): 'positive',
#  ('знать', 'меню'): 'positive',
#  ('закуска', 'к', 'пиву'): 'positive',
#  ('живопись',): 'positive',
#  ('живая', 'музыка'): 'positive',
#  ('жен-жен',): 'positive',
#  ('жевать',): 'negative',
#  ('ждем',): 'negative',
#  ('ждать', 'счет'): 'negative',
#  ('ждать', 'заказ'): 'positive',
#  ('жареный', 'осьминог'): 'positive',
#  ('жан-маке',): 'neutral',
#  ('ехать', 'приносить'): 'negative',
#  ('ехать',): 'neutral',
#  ('ель',): 'neutral',
#  ('елочка',): 'positive',
#  ('ели',): 'positive',
#  ('европейский', 'кухня'): 'positive',
#  ('жюльен',): 'neutral',
#  ('забирать',): 'negative',
#  ('заказываю', 'столик'): 'neutral',
#  ('заказывать', 'столик'): 'neutral',
#  ('заказывать',): 'neutral',
#  ('заказывали',): 'negative',
#  ('заказыва', 'стол'): 'positive',
#  ('заказать', 'обычный', 'столик'): 'negative',
#  ('заказанный', 'заранее'): 'neutral',
#  ('заказали', 'по', 'купону'): 'neutral',
#  ('заказали',): 'neutral',
#  ('заказала', 'столик'): 'neutral',
#  ('заказ', 'быть', 'принять'): 'negative',
#  ('заказ', 'быть', 'выполнить'): 'positive',
#  ('завернуть', 'с', 'себя'): 'positive',
#  ('забронировали', 'столик'): 'neutral',
#  ('забронировали', 'стол'): 'neutral',
#  ('выпить', 'пиво'): 'neutral',
#  ('выпили',): 'neutral',
#  ('казан', 'кабоб'): 'neutral',
#  ('барная', 'карта'): 'positive',
#  ('бесплатно',): 'positive',
#  ('береста', 'светлый'): 'negative',
#  ('белый', 'вино'): 'positive',
#  ('бекон', 'на', 'хрустяще', 'тосте', 'с', 'помидором', 'черри'): 'positive',
#  ('барную', 'стойка'): 'positive',
#  ('барная', 'стойка'): 'positive',
#  ('баклажан', 'запеченные'): 'positive',
#  ('баре',): 'both',
#  ('бараний', 'ножка'): 'positive',
#  ('бар',): 'positive',
#  ('банкетный', 'зал'): 'positive',
#  ('банкетн', 'зал'): 'neutral',
#  ('банкете',): 'positive',
#  ('бизнес', '-', 'ланчи'): 'positive',
#  ('бизо', 'с', 'сливками', 'и', 'фрукт'): 'positive',
#  ('блюдо', 'садж'): 'positive',
#  ('блюдо', 'китайский', 'кухня'): 'negative',
#  ('блюдо', 'из', 'осьминог'): 'positive',
#  ('блюдо', 'из', 'мясо', 'на', 'мангал'): 'positive',
#  ('блюдо', 'из', 'мясо'): 'positive',
#  ('блюдо', 'из', 'меню'): 'negative',
#  ('блюдо', 'восточный', 'кухня'): 'positive',
#  ('блюде',): 'positive',
#  ('блюд',): 'negative',
#  ('блинчик', 'с', 'мясо'): 'positive',
#  ('бифштекс',): 'neutral',
#  ('билл-хук',): 'neutral',
#  ('бальзамик',): 'positive',
#  ('базилик',): 'neutral',
#  ('выпивка',): 'positive',
#  ('Нельсон', 'пабе'): 'positive',
#  ('Чаплин', '-', 'холл'): 'neutral',
#  ('Цезарь', 'с', 'курица'): 'negative',
#  ('Цезарь',): 'neutral',
#  ('Судак',): 'positive',
#  ('Паста', 'с', 'морепродукт'): 'positive',
#  ('Паста',): 'positive',
#  ('Маргарита',): 'positive',
#  ('атомосфера',): 'positive',
#  ('ВИП', 'зона'): 'neutral',
#  ('Америка', 'мак'): 'neutral',
#  ('Америка',): 'both',
#  ('tefsi',): 'neutral',
#  ('legran',): 'positive',
#  ('da', 'albertone'): 'positive',
#  ('Le', 'glamure'): 'positive',
#  ('администрация', 'бара'): 'positive',
#  ('админы',): 'negative',
#  ('атмосфера', 'заведение'): 'positive',
#  ('ассортимент', 'блюдо'): 'positive',
#  ('ассортимент', 'бара'): 'positive',
#  ('ассортимент',): 'positive',
#  ('асахи',): 'positive',
#  ('апрель',): 'neutral',
#  ('аппетит',): 'neutral',
#  ('апельсиново', 'сока'): 'negative',
#  ('амадеусе',): 'neutral',
#  ('альмонд',): 'positive',
#  ('алкоголю',): 'positive',
#  ('алкогольных', 'напиток'): 'positive',
#  ('аквариум',): 'neutral',
#  ('блюдом',): 'positive',
#  ('бокал', 'коньяк'): 'neutral',
#  ('встреча',): 'positive',
#  ('выбор',): 'both',
#  ('вторы', 'блюдо'): 'neutral',
#  ('второй', 'зал'): 'positive',
#  ('второй', 'блюдо'): 'neutral',
#  ('второй',): 'neutral',
#  ('встречают',): 'positive',
#  ('бокал', 'красный', 'сухой', 'вино'): 'neutral',
#  ('встретила',): 'positive',
#  ('вручило', 'меню'): 'neutral',
#  ('времяпрепровождение',): 'positive',
#  ('впечатление', 'от', 'посещение'): 'positive',
#  ('впечатление', 'остаться'): 'positive',
#  ('выбор', 'алкогольных', 'коктейлей'): 'positive',
#  ('выбор', 'вина'): 'positive',
#  ('выпечки',): 'neutral',
#  ('выпечка',): 'positive',
#  ('выпекает',): 'positive',
#  ('выносить',): 'negative',
#  ('выносили',): 'negative',
#  ('вынести',): 'positive',
#  ('выбрать',): 'positive',
#  ('выбор', 'салат'): 'positive',
#  ('выбор', 'по', 'меню', 'и', 'напитка'): 'positive',
#  ('выбор', 'коктейлей'): 'positive',
#  ('выбор', 'закусок'): 'positive',
#  ('выбор', 'еда'): 'negative',
#  ('выбор', 'десерт'): 'positive',
#  ('выбор', 'горячий'): 'negative',
#  ('восточный', 'экспресс'): 'positive',
#  ('вазочка', 'с', 'виноград'): 'positive',
#  ('бульон', 'с', 'мясо'): 'neutral',
#  ('булочка',): 'positive',
#  ('буженина', 'на', 'грило'): 'positive',
#  ('бронь', 'столик'): 'neutral',
#  ('бронировать', 'столик'): 'neutral',
#  ('бронировать',): 'positive',
#  ('бронирование', 'столик', 'по', 'телефон'): 'neutral',
#  ('бронирование', 'столик'): 'neutral',
#  ('бронировали', 'столик'): 'neutral',
#  ('бронировали', 'стол'): 'neutral',
#  ('борщ', 'с', 'копченосте'): 'positive',
#  ('большой', 'экран'): 'positive',
#  ('большой', 'выбор'): 'positive',
#  ('бокало',): 'positive',
#  ('бюджетно',): 'positive',
#  ('вайнштефан', 'светлый'): 'positive',
#  ('внимание',): 'positive',
#  ('васаби',): 'negative',
#  ('внешний', 'вид', 'зал'): 'positive',
#  ('владелец',): 'positive',
#  ('вкусный',): 'positive',
#  ('вишно',): 'positive',
#  ('вишневый', 'штрудель'): 'positive',
#  ('вишневый', 'пирог', 'с', 'фисташков', 'кремо'): 'positive',
#  ('винная', 'карта'): 'positive',
#  ('винишко',): 'neutral',
#  ('визит',): 'positive',
#  ('вид', 'в', 'зал'): 'positive',
#  ('вечер', 'пройти'): 'positive',
#  ('весь', 'убирать'): 'positive',
#  ('вести',): 'positive',
#  ('веранда',): 'neutral',
#  ('вежливые',): 'positive',
#  ('итоговый', 'сумма'): 'negative',
#  ('какаоке',): 'positive',
#  ('пиццо',): 'negative',
#  ('обслуживаль',): 'positive',
#  ('обстановка', 'ресторан'): 'positive',
#  ('обслужила',): 'positive',
#  ('обслуживающая',): 'positive',
#  ('обслуживать', 'гость'): 'negative',
#  ('обслуживать',): 'positive',
#  ('обслуживало',): 'positive',
#  ('нижний', 'зал'): 'neutral',
#  ('обслуживали',): 'positive',
#  ('обслуга',): 'negative',
#  ('облицовка', 'стена'): 'positive',
#  ('обтановка',): 'positive',
#  ('общий', 'оценка', 'ресторану'): 'positive',
#  ('объедятся',): 'positive',
#  ('ответить', 'на', 'мой', 'вопрос'): 'positive',
#  ('отварный', 'креветки'): 'neutral',
#  ('осьминог',): 'positive',
#  ('острый',): 'neutral',
#  ('основной', 'зал'): 'negative',
#  ('основной', 'блюдо'): 'positive',
#  ('организовывать',): 'positive',
#  ('оргазм',): 'positive',
#  ('оливки',): 'neutral',
#  ('овощной', 'гарнир'): 'positive',
#  ('овощ', 'с', 'моцарелла'): 'negative',
#  ('овощ', 'на', 'грило'): 'positive',
#  ('обед',): 'positive',
#  ('нести', 'заказ'): 'negative',
#  ('мраморно', 'говядин'): 'positive',
#  ('мясное', 'блюдо'): 'positive',
#  ('на', 'вкус'): 'negative',
#  ('мясо', 'на', 'мангал'): 'positive',
#  ('мясной', 'чипс', 'из', 'говядина'): 'positive',
#  ('мясной', 'стейк'): 'negative',
#  ('мясной', 'блюдо'): 'positive',
#  ('мясной',): 'positive',
#  ('мясное',): 'positive',
#  ('некурящемо', 'зал'): 'positive',
#  ('мясная', 'нарезка'): 'positive',
#  ('музыкальный', 'фон'): 'positive',
#  ('музыкальный', 'сопровождение'): 'positive',
#  ('музыкальный', 'коллектив'): 'positive',
#  ('мужчина', 'из', 'гардероб'): 'positive',
#  ('набор', 'блюдо'): 'positive',
#  ('накладывали',): 'negative',
#  ('накопительно', 'скидку'): 'positive',
#  ('накормили',): 'positive',
#  ('некурящая', 'зона'): 'positive',
#  ('недорогое',): 'positive',
#  ('невский', '166'): 'neutral',
#  ('небо',): 'neutral',
#  ('не', 'курящий', 'зал'): 'positive',
#  ('не', '"', 'обслуживали', '"'): 'negative',
#  ('начинка',): 'positive',
#  ('настроение',): 'negative',
#  ('настойка',): 'positive',
#  ('народ', 'быть', 'не', 'очень', 'много'): 'positive',
#  ('наполеон',): 'positive',
#  ('напоили',): 'positive',
#  ('накрыть', 'стол'): 'positive',
#  ('отвечать',): 'positive',
#  ('отворачивался',): 'negative',
#  ('отделка',): 'neutral',
#  ('паэлью', 'с', 'курица', 'и', 'кролик'): 'neutral',
#  ('песня',): 'positive',
#  ('перчики', 'халапен'): 'positive',
#  ('перечный', 'стейк'): 'positive',
#  ('пересесть',): 'positive',
#  ('перепробовали',): 'positive',
#  ('первый', 'зал'): 'positive',
#  ('пенно', '4', 'сыр'): 'neutral',
#  ('патио', 'на', 'невском'): 'positive',
#  ('отдельный', 'зал'): 'positive',
#  ('пасту', 'с', 'морепродукт'): 'positive',
#  ('пасту', 'с', 'креветками'): 'neutral',
#  ('пасту', 'карбонар'): 'neutral',
#  ('пасту', '4', 'сыр'): 'positive',
#  ('паста', 'с', 'лососем'): 'positive',
#  ('петь',): 'positive',
#  ('печенай', 'груша'): 'positive',
#  ('пианистка',): 'positive',
#  ('пивной', 'бар'): 'positive',
#  ('пицца', 'на', 'тонкий', 'тест'): 'positive',
#  ('пицц',): 'positive',
#  ('пирожок', 'к', 'первый', 'блюдо'): 'neutral',
#  ('пирожной',): 'neutral',
#  ('пирожное',): 'neutral',
#  ('пили',): 'positive',
#  ...}

# %%
dev_texts = pd.read_csv('dev_reviews.txt', delimiter='\t', names=['text_id', 'text'])

# %%
dev_texts
# Out:
#     text_id                                               text
# 0     13823  Зашли в"аппетит" случайно.Не смотря на то,что ...
# 1      1427  Здравствуйте!Посетили ваше заведение вчера пер...
# 2     16714  Были в пятницу (19.03.10), заказывали столик д...
# 3       797  Были в ресторане 2 раза. Один раз днем, все по...
# 4     34710  Удивляюсь отзывам про хорошее обслуживание. Бы...
# ..      ...                                                ...
# 66     9216  Вы брали этот ресторан так как он близко от до...
# 67     8996  Были с друзьями в пабе Метрополь, всё очень по...
# 68    38299  Случайно увидели акцию на сайте купонов, решил...
# 69    37819  Очень долго выбирали ресторан на Новогодний ка...
# 70    11770  Была пару раз в пабе, очень понравилось. Вкусн...
#
# [71 rows x 2 columns]

# %% [markdown]
# Длины упоминаний аспектов в трейне:

# %%
Counter([len(x) for x in best_mention_sentiment.keys()])
# Out:
# Counter({1: 591, 2: 321, 3: 158, 4: 61, 5: 24, 6: 12, 7: 5, 9: 2, 10: 1, 8: 1})

# %% [markdown]
# Будем учитывать только упоминания длиной 1-5 токенов:

# %%
def label_texts(text, mentions, sentiments, max_len=5):
    tokenized = [word for sent in nlp(text).sentences for word in sent.words]
    text_end = len(tokenized)
    for i, token in enumerate(tokenized):
        for l in reversed(range(max_len)):
            if i + l > text_end:
                continue
            span = tokenized[i:i + l]
            key = tuple([t.lemma for t in span])
            if key in mentions:
                start, end = span[0].start_char, span[-1].end_char
                yield mentions[key], text[start:end], start, end, sentiments[key]
                break

# %% [markdown]
# Применяем частотные данные к текстам из dev:

# %%
with open('dev_pred_aspects.txt', 'w') as f:
    for text, idx in zip(dev_texts['text'], dev_texts['text_id']):
        for asp in label_texts(text, best_mention_cat, best_mention_sentiment):
            print(idx, *asp, sep="\t", file=f)

# %% [markdown]
# # Baseline 3
#
# Посчитаем упоминания аспектов с предсказанной тональностью, припишем
# - `absence` - если нет упоминаний данной категории
# - `both` - если есть упоминания с разной тональностью
# - `positive/neutral/negative` - если все упоминания одной тональности

# %%
CATEGORIES = ['Whole', 'Interior', 'Service', 'Food', 'Price']

# %%
def get_full_sentiment(text, mentions, sentiment, max_len=5):
    asp_counter = defaultdict(Counter)
    for asp in label_texts(text, best_mention_cat, best_mention_sentiment, max_len):
        category, *_, sentiment = asp
        asp_counter[category][sentiment] += 1
    for c in CATEGORIES:
        if not asp_counter[c]:
            s = 'absence'
        elif len(asp_counter[c]) == 1:
            s = asp_counter[c].most_common(1)[0][0]
        else:
            s = 'both'
        yield c, s

# %%
with open('dev_pred_cats.txt', 'w') as f:
    for text, idx in zip(dev_texts['text'], dev_texts['text_id']):
        for c, s in get_full_sentiment(text, best_mention_cat, best_mention_sentiment):
            print(idx, c, s, sep="\t", file=f)
